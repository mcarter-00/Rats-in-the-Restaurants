# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
# Get datasets using Los Angeles County API
inspections_dataset = pd.read_csv("./Resources/LOS_ANGELES_COUNTY_RESTAURANT_AND_MARKET_INSPECTIONS.csv")
violations_dataset = pd.read_csv("./Resources/LOS_ANGELES_COUNTY_RESTAURANT_AND_MARKET_VIOLATIONS.csv")

# %%
# Create Inspections DataFrame
inspections_df = pd.DataFrame(inspections_dataset)
inspections_df.head()
# Out:
#    :@computed_region_cbw7_skn5  :@computed_region_gj26_y8x3  \
# 0                          5.0                        295.0
# 1                          2.0                        439.0
# 2                          1.0                        105.0
# 3                          3.0                        395.0
# 4                          3.0                          1.0
#
#    :@computed_region_pft9_733t  :@computed_region_x8wy_s94z  \
# 0                       1629.0                      20146.0
# 1                        846.0                      23668.0
# 2                       2226.0                      10148.0
# 3                       1571.0                      19730.0
# 4                        360.0                       4276.0
#
#              activity_date employee_id  \
# 0  2018-09-10T00:00:00.000   EE0000495
# 1  2018-07-19T00:00:00.000   EE0001130
# 2  2018-08-15T00:00:00.000   EE0000500
# 3  2018-07-16T00:00:00.000   EE0000045
# 4  2018-09-07T00:00:00.000   EE0000526
#
#                             facility_address  facility_city facility_id  \
# 0                        203 W OLIVE AVE # C        BURBANK   FA0242046
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108    LOS ANGELES   FA0252769
# 2                             1515 E AMAR RD    WEST COVINA   FA0011237
# 3                          13560 ROSCOE BLVD  PANORAMA CITY   FA0061073
# 4                            29002 AGOURA RD   AGOURA HILLS   FA0252595
#
#                       facility_name  ...                   owner_name  \
# 0              SERVERY- NICKELODEON  ...  GUCKENHEIMER SERVICES, LLC.
# 1                   TOMS JR BURGERS  ...           ANASTACIOS POLITIS
# 2                    DJ BIBINGKAHAN  ...   DJ BIBINGKAHAN CORPORATION
# 3                     DOROSE LIQUOR  ...               KULWINDER KAUR
# 4  MEJICO GRILL AND TEQUILLA LOUNGE  ...                JUAN C OROZCO
#
#                           pe_description program_element_pe  \
# 0     RESTAURANT (31-60) SEATS HIGH RISK               1635
# 1      RESTAURANT (0-30) SEATS HIGH RISK               1632
# 2  RESTAURANT (0-30) SEATS MODERATE RISK               1631
# 3  FOOD MKT RETAIL (1-1,999 SF) LOW RISK               1610
# 4    RESTAURANT (151 + ) SEATS HIGH RISK               1641
#
#                        program_name program_status  record_id score  \
# 0              SERVERY- NICKELODEON         ACTIVE  PR0190194    96
# 1                   TOMS JR BURGERS         ACTIVE  PR0202127    98
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE  PR0035416    98
# 3                     DOROSE LIQUOR         ACTIVE  PR0027907    91
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE  PR0201914    90
#
#    serial_number service_code service_description
# 0      DARRFUZBW            1  ROUTINE INSPECTION
# 1      DA0XQVMTN            1  ROUTINE INSPECTION
# 2      DAMPOJNY8            1  ROUTINE INSPECTION
# 3      DAUTU3DPD            1  ROUTINE INSPECTION
# 4      DAUEU4NGF            1  ROUTINE INSPECTION
#
# [5 rows x 25 columns]

# %%
# Create Violations DataFrame
violations_df = pd.DataFrame(violations_dataset)
violations_df.head()
# Out:
#    points serial_number violation_code  \
# 0       2     DA000211Z           F006
# 1       1     DA000211Z           F044
# 2       2     DA000211Z           F014
# 3       1     DA000211Z           F029
# 4       1     DA000211Z           F035
#
#                                violation_description   violation_status
# 0  # 06. Adequate handwashing facilities supplied...  OUT OF COMPLIANCE
# 1  # 44. Floors, walls and ceilings: properly bui...  OUT OF COMPLIANCE
# 2   # 14. Food contact surfaces: clean and sanitized  OUT OF COMPLIANCE
# 3  # 29. Toxic substances properly identified, st...  OUT OF COMPLIANCE
# 4  # 35. Equipment/Utensils - approved; installed...  OUT OF COMPLIANCE

# %% [markdown]
# ## Inspect the Data - Perform Exploratory Data Analysis

# %%
# Get the column names in each DataFrame
print(inspections_df.columns)
print(violations_df.columns)
# Out:
# Index([':@computed_region_cbw7_skn5', ':@computed_region_gj26_y8x3',
#        ':@computed_region_pft9_733t', ':@computed_region_x8wy_s94z',
#        'activity_date', 'employee_id', 'facility_address', 'facility_city',
#        'facility_id', 'facility_name', 'facility_state', 'facility_zip',
#        'geocoded_column', 'grade', 'owner_id', 'owner_name', 'pe_description',
#        'program_element_pe', 'program_name', 'program_status', 'record_id',
#        'score', 'serial_number', 'service_code', 'service_description'],
#       dtype='object')
# Index(['points', 'serial_number', 'violation_code', 'violation_description',
#        'violation_status'],
#       dtype='object')

# %%
# Get the data types for each column in Inspections DataFrame
inspections_df.dtypes
# Out:
# :@computed_region_cbw7_skn5    float64
# :@computed_region_gj26_y8x3    float64
# :@computed_region_pft9_733t    float64
# :@computed_region_x8wy_s94z    float64
# activity_date                   object
# employee_id                     object
# facility_address                object
# facility_city                   object
# facility_id                     object
# facility_name                   object
# facility_state                  object
# facility_zip                    object
# geocoded_column                 object
# grade                           object
# owner_id                        object
# owner_name                      object
# pe_description                  object
# program_element_pe               int64
# program_name                    object
# program_status                  object
# record_id                       object
# score                            int64
# serial_number                   object
# service_code                     int64
# service_description             object
# dtype: object

# %%
# Get the data types for each column in Violations DataFrame
violations_df.dtypes
# Out:
# points                    int64
# serial_number            object
# violation_code           object
# violation_description    object
# violation_status         object
# dtype: object

# %%
# Check for null values in Inspections DataFrame
inspections_df.isnull().sum()
# Out:
# :@computed_region_cbw7_skn5    32
# :@computed_region_gj26_y8x3    32
# :@computed_region_pft9_733t    32
# :@computed_region_x8wy_s94z    32
# activity_date                   0
# employee_id                     0
# facility_address                0
# facility_city                   0
# facility_id                     0
# facility_name                   0
# facility_state                  0
# facility_zip                    0
# geocoded_column                32
# grade                           0
# owner_id                        0
# owner_name                      0
# pe_description                  0
# program_element_pe              0
# program_name                    0
# program_status                  0
# record_id                       0
# score                           0
# serial_number                   0
# service_code                    0
# service_description             0
# dtype: int64

# %%
# Check for null values in Violations DataFrame
violations_df.isnull().sum()
# Out:
# points                   0
# serial_number            0
# violation_code           0
# violation_description    0
# violation_status         0
# dtype: int64

# %%
# Drop columns from Inspections DataFrame
inspections_df = inspections_df.drop(columns = [":@computed_region_cbw7_skn5", 
                                                ":@computed_region_pft9_733t", 
                                                ":@computed_region_gj26_y8x3", 
                                                ":@computed_region_x8wy_s94z",])
inspections_df
# Out:
#                activity_date employee_id  \
# 0    2018-09-10T00:00:00.000   EE0000495
# 1    2018-07-19T00:00:00.000   EE0001130
# 2    2018-08-15T00:00:00.000   EE0000500
# 3    2018-07-16T00:00:00.000   EE0000045
# 4    2018-09-07T00:00:00.000   EE0000526
# 5    2018-09-18T00:00:00.000   EE0000437
# 6    2018-09-18T00:00:00.000   EE0001121
# 7    2018-07-17T00:00:00.000   EE0000399
# 8    2018-07-12T00:00:00.000   EE0000946
# 9    2018-08-24T00:00:00.000   EE0001002
# 10   2018-09-18T00:00:00.000   EE0000025
# 11   2018-09-15T00:00:00.000   EE0000633
# 12   2018-08-01T00:00:00.000   EE0000997
# 13   2018-08-03T00:00:00.000   EE0000011
# 14   2018-08-09T00:00:00.000   EE0001098
# 15   2018-08-02T00:00:00.000   EE0000847
# 16   2018-09-12T00:00:00.000   EE0000161
# 17   2018-08-21T00:00:00.000   EE0000338
# 18   2018-08-29T00:00:00.000   EE0000854
# 19   2018-09-04T00:00:00.000   EE0000483
# 20   2018-07-19T00:00:00.000   EE0000360
# 21   2018-08-14T00:00:00.000   EE0000742
# 22   2017-09-01T00:00:00.000   EE0000503
# 23   2018-07-24T00:00:00.000   EE0000740
# 24   2018-09-06T00:00:00.000   EE0000318
# 25   2018-08-15T00:00:00.000   EE0000161
# 26   2018-08-02T00:00:00.000   EE0000924
# 27   2018-07-17T00:00:00.000   EE0000873
# 28   2018-07-18T00:00:00.000   EE0000495
# 29   2018-09-14T00:00:00.000   EE0001164
# ..                       ...         ...
# 970  2018-09-04T00:00:00.000   EE0001124
# 971  2018-07-17T00:00:00.000   EE0000965
# 972  2018-07-27T00:00:00.000   EE0000526
# 973  2018-08-01T00:00:00.000   EE0000946
# 974  2018-08-28T00:00:00.000   EE0000188
# 975  2018-09-18T00:00:00.000   EE0000031
# 976  2018-07-13T00:00:00.000   EE0000721
# 977  2018-09-05T00:00:00.000   EE0001120
# 978  2018-07-16T00:00:00.000   EE0001011
# 979  2018-09-04T00:00:00.000   EE0000965
# 980  2018-07-25T00:00:00.000   EE0000500
# 981  2018-07-13T00:00:00.000   EE0000709
# 982  2018-07-27T00:00:00.000   EE0000578
# 983  2018-07-20T00:00:00.000   EE0000731
# 984  2018-08-08T00:00:00.000   EE0000355
# 985  2018-08-28T00:00:00.000   EE0000126
# 986  2018-08-24T00:00:00.000   EE0000727
# 987  2018-09-13T00:00:00.000   EE0000031
# 988  2018-09-13T00:00:00.000   EE0000957
# 989  2018-07-19T00:00:00.000   EE0001003
# 990  2018-08-15T00:00:00.000   EE0000506
# 991  2018-08-10T00:00:00.000   EE0000145
# 992  2018-08-24T00:00:00.000   EE0001073
# 993  2018-08-20T00:00:00.000   EE0001111
# 994  2018-09-19T00:00:00.000   EE0001167
# 995  2018-08-09T00:00:00.000   EE0001003
# 996  2018-09-12T00:00:00.000   EE0000999
# 997  2018-09-07T00:00:00.000   EE0000520
# 998  2018-08-02T00:00:00.000   EE0000799
# 999  2018-07-18T00:00:00.000   EE0000382
#
#                               facility_address          facility_city  \
# 0                          203 W OLIVE AVE # C                BURBANK
# 1    1030 W MARTIN LUTHER KING JR BLVD STE 108            LOS ANGELES
# 2                               1515 E AMAR RD            WEST COVINA
# 3                            13560 ROSCOE BLVD          PANORAMA CITY
# 4                              29002 AGOURA RD           AGOURA HILLS
# 5                            5725 FLORENCE AVE           BELL GARDENS
# 6                   11540 HAWTHORNE BLVD STE A              HAWTHORNE
# 7                             6032 RESEDA BLVD                TARZANA
# 8                           2530 GLENDALE BLVD            LOS ANGELES
# 9                             9755 CULVER BLVD            CULVER CITY
# 10                          730 N VICTORY BLVD                BURBANK
# 11                          3939 S FIGUEROA ST            LOS ANGELES
# 12                              1213 S SOTO ST            LOS ANGELES
# 13                         13839 FOOTHILL BLVD                 SYLMAR
# 14                           9319 S ALAMEDA ST            LOS ANGELES
# 15                         16836 DEVONSHIRE ST          GRANADA HILLS
# 16                         14562 E VALLEY BLVD              LA PUENTE
# 17              13050 SAN VICENTE BLVD STE 114            LOS ANGELES
# 18                               3451 W 6TH ST            LOS ANGELES
# 19                     26238 BOUQUET CANYON RD          SANTA CLARITA
# 20                        319 E 2ND ST STE 206            LOS ANGELES
# 21                             659 E ARROW HWY                  AZUSA
# 22                       15234 E WHITTIER BLVD               WHITTIER
# 23                             1820 MARENGO ST            LOS ANGELES
# 24                        1320 W GLENOAKS BLVD               GLENDALE
# 25                               13925 AMAR RD              LA PUENTE
# 26                              340 N MAPLE DR          BEVERLY HILLS
# 27                            8720 SUNSET BLVD         WEST HOLLYWOOD
# 28                        111 RAGING WATERS DR              SAN DIMAS
# 29                      4716 1/2 ADMIRALTY WAY         MARINA DEL REY
# ..                                         ...                    ...
# 970                          631 FOOTHILL BLVD   LA CANADA FLINTRIDGE
# 971                        1774 E FLORENCE AVE            LOS ANGELES
# 972                              5013 KANAN RD           AGOURA HILLS
# 973                         2366 GLENDALE BLVD            LOS ANGELES
# 974                      11725 GARVEY AVE # 6C               EL MONTE
# 975                          7918 NORWALK BLVD               WHITTIER
# 976                         4228 S AVALON BLVD            LOS ANGELES
# 977                500 N ATLANTIC BLVD STE 166          MONTEREY PARK
# 978                        812 N EVERGREEN AVE            LOS ANGELES
# 979                        2112 E FLORENCE AVE            WALNUT PARK
# 980                      3648 S NOGALES ST # C            WEST COVINA
# 981                        5269 HOLLYWOOD BLVD            LOS ANGELES
# 982                         20060 VENTURA BLVD         WOODLAND HILLS
# 983                      1664 W SEPULVEDA BLVD            HARBOR CITY
# 984                     200 S SAN GABRIEL BLVD            SAN GABRIEL
# 985                            7 PENINSULA CTR  ROLLING HILLS ESTATES
# 986                     11684 SAN VICENTE BLVD            LOS ANGELES
# 987                     5331 S WORKMAN MILL RD               WHITTIER
# 988                           150 S BEVERLY DR          BEVERLY HILLS
# 989                     5311 SANTA MONICA BLVD            LOS ANGELES
# 990                           225 LINCOLN BLVD                 VENICE
# 991                        5500 N WOODRUFF AVE               LAKEWOOD
# 992                        10727 S CENTRAL AVE            LOS ANGELES
# 993                      1453 W MANCHESTER AVE            LOS ANGELES
# 994                          330 N ALVARADO ST            LOS ANGELES
# 995                           5059 MELROSE AVE            LOS ANGELES
# 996                             2360 PICO BLVD           SANTA MONICA
# 997                         5947 FALLBROOK AVE         WOODLAND HILLS
# 998                            8451 BEVERLY RD            PICO RIVERA
# 999                        1003 S GLENDORA AVE            WEST COVINA
#
#     facility_id                     facility_name facility_state facility_zip  \
# 0     FA0242046              SERVERY- NICKELODEON             CA        91502
# 1     FA0252769                   TOMS JR BURGERS             CA   90037-1867
# 2     FA0011237                    DJ BIBINGKAHAN             CA        91792
# 3     FA0061073                     DOROSE LIQUOR             CA        91402
# 4     FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE             CA        91301
# 5     FA0158101                 MCDONALD'S #10681             CA        90201
# 6     FA0264511          HULI HULI HAWAIIAN GRILL             CA        90250
# 7     FA0011473                 BURRITOS EL CHAVO             CA        91356
# 8     FA0017398                      CVS/PHARMACY             CA        90039
# 9     FA0138817                         CAFE VIDA             CA        90232
# 10    FA0004911                BARRAGAN'S MEXICAN             CA        91502
# 11    FA0258944                              LAFC             CA        90037
# 12    FA0054833           WINCHELL'S DONUTS #9517             CA        90023
# 13    FA0008027                BAMBINO'S PIZZERIA             CA        91342
# 14    FA0177577                         GI LIQUOR             CA        90002
# 15    FA0242453                PANERA BREAD #4241             CA        91344
# 16    FA0034962                   LA PUENTE SHELL             CA        91746
# 17    FA0034788                 LE PAIN QUOTIDIEN             CA        90049
# 18    FA0163047                            ESCALA             CA        90020
# 19    FA0240044                        MY HOT POT             CA        91350
# 20    FA0041946               ZENCU SUSHI & GRILL             CA        90012
# 21    FA0003277     ALDOLINO'S ITALIAN RESTAURANT             CA        91740
# 22    FA0005024                    BASKIN ROBBINS             CA        90603
# 23    FA0037462                    MARIA'S BAKERY             CA        90033
# 24    FA0020486      LA BANQUET S -GLENOAKS BALLR             CA        91201
# 25    FA0058380                   BIG SAVER FOODS             CA        91746
# 26    FA0005479         BEVERLY HILLS TENNIS CLUB             CA        90210
# 27    FA0179818                   TOCAYA ORGANICA             CA        90069
# 28    FA0140146                     RAGING WATERS             CA   91773-3928
# 29    FA0165647                    KREATION JUICE             CA        90292
# ..          ...                               ...            ...          ...
# 970   FA0035863                 LOS GRINGOS LOCOS             CA        91011
# 971   FA0225945                 BOYS BURGERS NO.1             CA        90001
# 972   FA0165525                      POPPED FRESH             CA        91301
# 973   FA0046135                   RED LION TAVERN             CA        90039
# 974   FA0138042            LA VICTORIA RESTAURANT             CA        91732
# 975   FA0025761                          GNC 8086             CA        90606
# 976   FA0010013              CORONADO MEAT MARKET             CA        90011
# 977   FA0262281                          HULAFISH             CA   91754-7735
# 978   FA0021493             EL TEPEYAC RESTAURANT             CA        90063
# 979   FA0238959               COLD STONE CREAMERY             CA   90255-5617
# 980   FA0203670                      JIN TEAHOUSE             CA        91792
# 981   FA0261457                   PA ORD NOODLE 3             CA        90027
# 982   FA0252479          AFC SUSHI @ RALPHS #0070             CA        91364
# 983   FA0071295          SUBWAY SANDWICH & SALADS             CA        90710
# 984   FA0262726           TASTY CHOICE RESTAURANT             CA        91776
# 985   FA0028066                   PAVILIONS #2233             CA        90274
# 986   FA0027070            HARRY'S WINE & SPIRITS             CA        90049
# 987   FA0061355           EL CAMINO MEXICAN GRILL             CA        90601
# 988   FA0028394                  PICCOLO PARADISO             CA        90212
# 989   FA0019185                       JONS MARKET             CA        90029
# 990   FA0055176            WHOLE FOODS MARKET #43             CA        90291
# 991   FA0073623                        VONS #2209             CA        90713
# 992   FA0224903                    EXPRESS BURGER             CA        90059
# 993   FA0006575                 BURGER KING #1346             CA        90047
# 994   FA0012496                     EL POLLO LOCO             CA        90026
# 995   FA0163076                  PRODUCE FOR LESS             CA   90038-4115
# 996   FA0055749                   YOSHINOYA #1128             CA        90405
# 997   FA0001328            JIM'S FALLBROOK MARKET             CA        91367
# 998   FA0166889                     RICK'S MARKET             CA   90660-2200
# 999   FA0261857           WT HIBACHI GRILL BUFFET             CA        91790
#
#                                        geocoded_column grade  ...  \
# 0    {'type': 'Point', 'coordinates': [-118.314661,...     A  ...
# 1    {'type': 'Point', 'coordinates': [-118.292543,...     A  ...
# 2    {'type': 'Point', 'coordinates': [-117.913926,...     A  ...
# 3    {'type': 'Point', 'coordinates': [-118.428399,...     A  ...
# 4    {'type': 'Point', 'coordinates': [-118.756808,...     A  ...
# 5    {'type': 'Point', 'coordinates': [-118.163665,...     A  ...
# 6    {'type': 'Point', 'coordinates': [-118.352484,...     A  ...
# 7    {'type': 'Point', 'coordinates': [-118.536014,...     A  ...
# 8    {'type': 'Point', 'coordinates': [-118.259145,...     A  ...
# 9    {'type': 'Point', 'coordinates': [-118.396347,...     A  ...
# 10   {'type': 'Point', 'coordinates': [-118.32036, ...     A  ...
# 11   {'type': 'Point', 'coordinates': [-118.282741,...     A  ...
# 12   {'type': 'Point', 'coordinates': [-118.219524,...     A  ...
# 13   {'type': 'Point', 'coordinates': [-118.434764,...     A  ...
# 14   {'type': 'Point', 'coordinates': [-118.229708,...     A  ...
# 15   {'type': 'Point', 'coordinates': [-118.499318,...     A  ...
# 16   {'type': 'Point', 'coordinates': [-117.975091,...     A  ...
# 17   {'type': 'Point', 'coordinates': [-118.491168,...     A  ...
# 18   {'type': 'Point', 'coordinates': [-118.296846,...     B  ...
# 19   {'type': 'Point', 'coordinates': [-118.541538,...     A  ...
# 20   {'type': 'Point', 'coordinates': [-118.241224,...     A  ...
# 21   {'type': 'Point', 'coordinates': [-117.897698,...     A  ...
# 22                                                 NaN     A  ...
# 23   {'type': 'Point', 'coordinates': [-118.211204,...     A  ...
# 24   {'type': 'Point', 'coordinates': [-118.283813,...     A  ...
# 25   {'type': 'Point', 'coordinates': [-117.973572,...     A  ...
# 26   {'type': 'Point', 'coordinates': [-118.393518,...     A  ...
# 27   {'type': 'Point', 'coordinates': [-118.38113, ...     A  ...
# 28   {'type': 'Point', 'coordinates': [-117.807721,...     A  ...
# 29   {'type': 'Point', 'coordinates': [-118.439713,...     A  ...
# ..                                                 ...   ...  ...
# 970  {'type': 'Point', 'coordinates': [-118.192734,...     A  ...
# 971  {'type': 'Point', 'coordinates': [-118.240866,...     A  ...
# 972  {'type': 'Point', 'coordinates': [-118.761723,...     A  ...
# 973  {'type': 'Point', 'coordinates': [-118.259223,...     A  ...
# 974  {'type': 'Point', 'coordinates': [-118.023128,...     A  ...
# 975  {'type': 'Point', 'coordinates': [-118.074248,...     A  ...
# 976  {'type': 'Point', 'coordinates': [-118.265254,...     A  ...
# 977  {'type': 'Point', 'coordinates': [-118.134348,...     A  ...
# 978  {'type': 'Point', 'coordinates': [-118.197869,...     A  ...
# 979  {'type': 'Point', 'coordinates': [-118.233927,...     A  ...
# 980  {'type': 'Point', 'coordinates': [-117.886774,...     A  ...
# 981  {'type': 'Point', 'coordinates': [-118.30526, ...     A  ...
# 982  {'type': 'Point', 'coordinates': [-118.570688,...     A  ...
# 983  {'type': 'Point', 'coordinates': [-118.308159,...     A  ...
# 984  {'type': 'Point', 'coordinates': [-118.090994,...     A  ...
# 985  {'type': 'Point', 'coordinates': [-118.376461,...     A  ...
# 986  {'type': 'Point', 'coordinates': [-118.465246,...     A  ...
# 987  {'type': 'Point', 'coordinates': [-118.055715,...     A  ...
# 988  {'type': 'Point', 'coordinates': [-118.399087,...     A  ...
# 989  {'type': 'Point', 'coordinates': [-118.305154,...     A  ...
# 990  {'type': 'Point', 'coordinates': [-118.468615,...     A  ...
# 991  {'type': 'Point', 'coordinates': [-118.117065,...     A  ...
# 992  {'type': 'Point', 'coordinates': [-118.254184,...     C  ...
# 993  {'type': 'Point', 'coordinates': [-118.302025,...     A  ...
# 994  {'type': 'Point', 'coordinates': [-118.268173,...     A  ...
# 995  {'type': 'Point', 'coordinates': [-118.31062, ...     B  ...
# 996  {'type': 'Point', 'coordinates': [-118.465831,...     A  ...
# 997  {'type': 'Point', 'coordinates': [-118.623337,...     A  ...
# 998  {'type': 'Point', 'coordinates': [-118.08959, ...     A  ...
# 999  {'type': 'Point', 'coordinates': [-117.936658,...     C  ...
#
#                                  owner_name  \
# 0               GUCKENHEIMER SERVICES, LLC.
# 1                        ANASTACIOS POLITIS
# 2                DJ BIBINGKAHAN CORPORATION
# 3                            KULWINDER KAUR
# 4                             JUAN C OROZCO
# 5                   REDONDO ENTERPRISES LLC
# 6                        LH HAWAII BBQ INC.
# 7                            OCHOA,SALVADOR
# 8                  GARFIELD BEACH CVS, LLC.
# 9                       CCM CREATIONS, INC.
# 10                BARRAGAN'S RESTAURANT INC
# 11                       LEGENDS SPORTS LLC
# 12                 YUM YUM DONUT SHOPS INC.
# 13                     GUTIERREZ, HECTOR J.
# 14                        JARNAIL & B INC .
# 15                          RISEN BREAD LLC
# 16                               KIM, BRIAN
# 17                      PQ SAN VICENTE INC.
# 18                              WOOLEE INC.
# 19                           MY HOT POT LLC
# 20                             KATYAYA, INC
# 21                          ZARAZUA GABRIEL
# 22                   RAZZAK, MOHAMMED QADER
# 23                               LEE, MARIA
# 24                         SARKISSIAN, VREJ
# 25                UKA'S BIG SAVER FOODS INC
# 26             BEVERLY HILLS TENNIS CLUB IN
# 27                           EDL SUNSET LLC
# 28                   FESTIVAL FUN PARKS LLC
# 29            KREATION & ABBOTT KINNEY, INC
# ..                                      ...
# 970                   LOS GRINGOS LOCOS LLC
# 971                      PACIFIC BOYS, INC.
# 972                        POPPED FRESH LLC
# 973                     RAUDONAS LIUTAS INC
# 974                           PEREZ, OFELIA
# 975                         NICK & ERIC INC
# 976                          CORONADO, JOSE
# 977                       KALEY & CO., INC.
# 978                          EL TEPEYAC INC
# 979                       KANONI FAMILY INC
# 980                            JIN TEAHOUSE
# 981                       SIRIWAN RAJPRADIT
# 982  ADVANCED FRESH CONCEPTS FRANCHISE CORP
# 983                             WTC III INC
# 984                  MIMI TASTY CHOICE INC.
# 985                 THE VONS COMPANIES INC.
# 986                  HARRY'S WINE & SPIRITS
# 987                        VILLANUEVA, ALMA
# 988                CARNIVALE RESTAURANT INC
# 989                   BERBERIAN ENTERPRISES
# 990                WHOLE FOODS MARKET, INC.
# 991                 THE VONS COMPANIES INC.
# 992                          EXPRESS BURGER
# 993            METRO MANAGEMENT SYSTIEMS IN
# 994                     EL POLLO LOCO, INC.
# 995                           RUPINDER KAUR
# 996                 YOSHINOYA AMERICA, INC.
# 997             MCQUAID,MICHAEL AND PATRICK
# 998                           OSAMA IBRAHIM
# 999           WT HIBACHI GRILL BUFFET, INC.
#
#                               pe_description program_element_pe  \
# 0         RESTAURANT (31-60) SEATS HIGH RISK               1635
# 1          RESTAURANT (0-30) SEATS HIGH RISK               1632
# 2      RESTAURANT (0-30) SEATS MODERATE RISK               1631
# 3      FOOD MKT RETAIL (1-1,999 SF) LOW RISK               1610
# 4        RESTAURANT (151 + ) SEATS HIGH RISK               1641
# 5    RESTAURANT (61-150) SEATS MODERATE RISK               1637
# 6          RESTAURANT (0-30) SEATS HIGH RISK               1632
# 7         RESTAURANT (31-60) SEATS HIGH RISK               1635
# 8       FOOD MKT RETAIL (2,000+ SF) LOW RISK               1613
# 9         RESTAURANT (31-60) SEATS HIGH RISK               1635
# 10       RESTAURANT (151 + ) SEATS HIGH RISK               1641
# 11          RESTAURANT (0-30) SEATS LOW RISK               1630
# 12     RESTAURANT (0-30) SEATS MODERATE RISK               1631
# 13    RESTAURANT (31-60) SEATS MODERATE RISK               1634
# 14     FOOD MKT RETAIL (1-1,999 SF) LOW RISK               1610
# 15       RESTAURANT (61-150) SEATS HIGH RISK               1638
# 16     FOOD MKT RETAIL (1-1,999 SF) LOW RISK               1610
# 17       RESTAURANT (61-150) SEATS HIGH RISK               1638
# 18       RESTAURANT (61-150) SEATS HIGH RISK               1638
# 19        RESTAURANT (31-60) SEATS HIGH RISK               1635
# 20       RESTAURANT (61-150) SEATS HIGH RISK               1638
# 21       RESTAURANT (61-150) SEATS HIGH RISK               1638
# 22     RESTAURANT (0-30) SEATS MODERATE RISK               1630
# 23     RESTAURANT (0-30) SEATS MODERATE RISK               1631
# 24       RESTAURANT (151 + ) SEATS HIGH RISK               1641
# 25    FOOD MKT RETAIL (1-1,999 SF) HIGH RISK               1612
# 26       RESTAURANT (61-150) SEATS HIGH RISK               1638
# 27       RESTAURANT (151 + ) SEATS HIGH RISK               1641
# 28     RESTAURANT (0-30) SEATS MODERATE RISK               1631
# 29     FOOD MKT RETAIL (1-1,999 SF) LOW RISK               1610
# ..                                       ...                ...
# 970      RESTAURANT (61-150) SEATS HIGH RISK               1638
# 971        RESTAURANT (0-30) SEATS HIGH RISK               1632
# 972         RESTAURANT (0-30) SEATS LOW RISK               1630
# 973      RESTAURANT (61-150) SEATS HIGH RISK               1638
# 974       RESTAURANT (31-60) SEATS HIGH RISK               1635
# 975    FOOD MKT RETAIL (1-1,999 SF) LOW RISK               1610
# 976    FOOD MKT RETAIL (2,000+ SF) HIGH RISK               1615
# 977       RESTAURANT (31-60) SEATS HIGH RISK               1635
# 978      RESTAURANT (61-150) SEATS HIGH RISK               1638
# 979         RESTAURANT (0-30) SEATS LOW RISK               1630
# 980        RESTAURANT (0-30) SEATS HIGH RISK               1632
# 981        RESTAURANT (0-30) SEATS HIGH RISK               1632
# 982        RESTAURANT (0-30) SEATS HIGH RISK               1632
# 983    RESTAURANT (0-30) SEATS MODERATE RISK               1631
# 984      RESTAURANT (61-150) SEATS HIGH RISK               1638
# 985   FOOD MKT RETAIL (1-1,999 SF) HIGH RISK               1612
# 986    FOOD MKT RETAIL (1-1,999 SF) LOW RISK               1610
# 987       RESTAURANT (31-60) SEATS HIGH RISK               1635
# 988      RESTAURANT (61-150) SEATS HIGH RISK               1638
# 989     FOOD MKT RETAIL (2,000+ SF) LOW RISK               1615
# 990        RESTAURANT (0-30) SEATS HIGH RISK               1632
# 991     FOOD MKT RETAIL (2,000+ SF) LOW RISK               1613
# 992       RESTAURANT (31-60) SEATS HIGH RISK               1635
# 993  RESTAURANT (61-150) SEATS MODERATE RISK               1637
# 994      RESTAURANT (61-150) SEATS HIGH RISK               1638
# 995    FOOD MKT RETAIL (2,000+ SF) HIGH RISK               1615
# 996        RESTAURANT (0-30) SEATS HIGH RISK               1632
# 997    FOOD MKT RETAIL (2,000+ SF) HIGH RISK               1615
# 998    FOOD MKT RETAIL (1-1,999 SF) LOW RISK               1610
# 999      RESTAURANT (151 + ) SEATS HIGH RISK               1641
#
#                          program_name program_status  record_id score  \
# 0                SERVERY- NICKELODEON         ACTIVE  PR0190194    96
# 1                     TOMS JR BURGERS         ACTIVE  PR0202127    98
# 2             DJ BIBINGKAHAN BAKESHOP         ACTIVE  PR0035416    98
# 3                       DOROSE LIQUOR         ACTIVE  PR0027907    91
# 4    MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE  PR0201914    90
# 5                   MCDONALD'S #10681         ACTIVE  PR0146191    91
# 6            HULI HULI HAWAIIAN GRILL         ACTIVE  PR0215618    90
# 7                   BURRITOS EL CHAVO         ACTIVE  PR0005803    96
# 8                        CVS/PHARMACY         ACTIVE  PR0027636    93
# 9                           CAFE VIDA         ACTIVE  PR0123185    91
# 10                 BARRAGAN'S MEXICAN         ACTIVE  PR0023156    98
# 11   LAFC - 04.02.04 / CITY VIEW CLUB         ACTIVE  PR0209031    96
# 12            WINCHELL'S DONUTS #9517         ACTIVE  PR0015463    92
# 13                  BAMBINO'S PIZERIA         ACTIVE  PR0002731    91
# 14                          GI LIQUOR         ACTIVE  PR0170601    97
# 15                 PANERA BREAD #4241         ACTIVE  PR0190624    96
# 16                    LA PUENTE SHELL         ACTIVE  PR0028006    96
# 17                  LE PAIN QUOTIDIEN         ACTIVE  PR0017456    93
# 18                         CANDELARIA         ACTIVE  PR0151221    83
# 19                         MY HOT POT         ACTIVE  PR0188048    95
# 20                ZENCU SUSHI & GRILL         ACTIVE  PR0044601    92
# 21      ALDOLINO'S ITALIAN RESTAURANT         ACTIVE  PR0032442    95
# 22                     BASKIN ROBBINS         ACTIVE  PR0029297    92
# 23                     MARIA'S BAKERY         ACTIVE  PR0013043    90
# 24       LA BANQUET S -GLENOAKS BALLR         ACTIVE  PR0000683    93
# 25                    BIG SAVER FOODS         ACTIVE  PR0011628    92
# 26          BEVERLY HILLS TENNIS CLUB         ACTIVE  PR0007571    97
# 27                    TOCAYA ORGANICA         ACTIVE  PR0173474    91
# 28             PIPELINE PIZZA EXPRESS         ACTIVE  PR0021024    99
# 29                     KREATION JUICE         ACTIVE  PR0153978   100
# ..                                ...            ...        ...   ...
# 970                 LOS GRINGOS LOCOS         ACTIVE  PR0018093    93
# 971                 BOYS BURGERS NO.1         ACTIVE  PR0181264    91
# 972                      POPPED FRESH         ACTIVE  PR0153854    99
# 973                   RED LION TAVERN         ACTIVE  PR0015567    97
# 974            LA VICTORIA RESTAURANT         ACTIVE  PR0122271    90
# 975                          GNC 8086         ACTIVE  PR0008982    96
# 976              CORONADO MEAT MARKET         ACTIVE  PR0045354    91
# 977                          HULAFISH       INACTIVE  PR0212978    91
# 978             EL TEPEYAC RESTAURANT         ACTIVE  PR0005589   100
# 979               COLD STONE CREAMERY         ACTIVE  PR0186907    97
# 980                      JIN TEAHOUSE         ACTIVE  PR0176071    90
# 981                   PA ORD NOODLE 3         ACTIVE  PR0212027    92
# 982          AFC SUSHI @ RALPHS #0070         ACTIVE  PR0201752    96
# 983          SUBWAY SANDWICH & SALADS         ACTIVE  PR0009391    97
# 984           TASTY CHOICE RESTAURANT         ACTIVE  PR0213513    91
# 985       PAVILIONS #2233 - MEAT DEPT         ACTIVE  PR0033695    97
# 986            HARRY'S WINE & SPIRITS         ACTIVE  PR0041615    97
# 987           EL CAMINO MEXICAN GRILL         ACTIVE  PR0030814    96
# 988                 PICCOLO PARADISCO         ACTIVE  PR0039984    93
# 989                   JON'S MARKET #7         ACTIVE  PR0043069    97
# 990      WHOLEFOODS DELI/PREPARED FOO         ACTIVE  PR0027038    93
# 991                        VONS #2209         ACTIVE  PR0024692    95
# 992                    EXPRESS BURGER       INACTIVE  PR0180180    77
# 993                 BURGER KING #1346         ACTIVE  PR0010143    93
# 994                     EL POLLO LOCO         ACTIVE  PR0015865    93
# 995                  PRODUCE FOR LESS         ACTIVE  PR0151246    80
# 996          YOSHINOYA BEEF BOWL REST         ACTIVE  PR0000189    93
# 997            JIM'S FALLBROOK MARKET         ACTIVE  PR0026439    96
# 998                     RICK'S MARKET         ACTIVE  PR0157225    92
# 999           WT HIBACHI GRILL BUFFET         ACTIVE  PR0212492    75
#
#      serial_number service_code               service_description
# 0        DARRFUZBW            1                ROUTINE INSPECTION
# 1        DA0XQVMTN            1                ROUTINE INSPECTION
# 2        DAMPOJNY8            1                ROUTINE INSPECTION
# 3        DAUTU3DPD            1                ROUTINE INSPECTION
# 4        DAUEU4NGF            1                ROUTINE INSPECTION
# 5        DARQIUA45            1                ROUTINE INSPECTION
# 6        DA0JE0XXO            1                ROUTINE INSPECTION
# 7        DAGKKNDCV            1                ROUTINE INSPECTION
# 8        DACOHF2H4            1                ROUTINE INSPECTION
# 9        DACIDHL0U          401  OWNER INITIATED ROUTINE INSPECT.
# 10       DABWNUI3O            1                ROUTINE INSPECTION
# 11       DA30IVVSL            1                ROUTINE INSPECTION
# 12       DAN40VEF6            1                ROUTINE INSPECTION
# 13       DAIPLB050            1                ROUTINE INSPECTION
# 14       DAQHC9UMM            1                ROUTINE INSPECTION
# 15       DAERIHGIJ            1                ROUTINE INSPECTION
# 16       DAR1E1EVY            1                ROUTINE INSPECTION
# 17       DA0XCDE0H            1                ROUTINE INSPECTION
# 18       DAPCQ9VAR            1                ROUTINE INSPECTION
# 19       DAXHN6FYF            1                ROUTINE INSPECTION
# 20       DAJNK3M9V            1                ROUTINE INSPECTION
# 21       DA0RAQH09            1                ROUTINE INSPECTION
# 22       DADJBKMVN            1                ROUTINE INSPECTION
# 23       DA3ETVYNG            1                ROUTINE INSPECTION
# 24       DAGJFPDYA            1                ROUTINE INSPECTION
# 25       DA2NXQSSE            1                ROUTINE INSPECTION
# 26       DAWZLOB5R            1                ROUTINE INSPECTION
# 27       DATWYNKMQ            1                ROUTINE INSPECTION
# 28       DAYAKUS0H            1                ROUTINE INSPECTION
# 29       DAU2N88BR            1                ROUTINE INSPECTION
# ..             ...          ...                               ...
# 970      DAWCXSXTP            1                ROUTINE INSPECTION
# 971      DA3X7RIM0            1                ROUTINE INSPECTION
# 972      DAGB2ERHE            1                ROUTINE INSPECTION
# 973      DANLXHVRZ            1                ROUTINE INSPECTION
# 974      DA1ALMGT4            1                ROUTINE INSPECTION
# 975      DA0V5H0O6            1                ROUTINE INSPECTION
# 976      DA0UDKRBV            1                ROUTINE INSPECTION
# 977      DA2Q3CNEB            1                ROUTINE INSPECTION
# 978      DACBXMHT5            1                ROUTINE INSPECTION
# 979      DALDRUZT9            1                ROUTINE INSPECTION
# 980      DAYAP0NXQ            1                ROUTINE INSPECTION
# 981      DAMANYCBV            1                ROUTINE INSPECTION
# 982      DABAZWHWG            1                ROUTINE INSPECTION
# 983      DA4R85GBE            1                ROUTINE INSPECTION
# 984      DAU5VW1KS            1                ROUTINE INSPECTION
# 985      DAKM0ZZWW            1                ROUTINE INSPECTION
# 986      DATFCCYVJ            1                ROUTINE INSPECTION
# 987      DAHADERAA            1                ROUTINE INSPECTION
# 988      DABAEMSTR            1                ROUTINE INSPECTION
# 989      DAMGTCSOF            1                ROUTINE INSPECTION
# 990      DA42OUUK8            1                ROUTINE INSPECTION
# 991      DAPPVZ2GZ            1                ROUTINE INSPECTION
# 992      DA3LYP1JF            1                ROUTINE INSPECTION
# 993      DA0JFUP6U            1                ROUTINE INSPECTION
# 994      DAVZSS2JO            1                ROUTINE INSPECTION
# 995      DAYNOBKAY            1                ROUTINE INSPECTION
# 996      DAX6EQH2R            1                ROUTINE INSPECTION
# 997      DAUNLUNBV            1                ROUTINE INSPECTION
# 998      DANUGOBDL            1                ROUTINE INSPECTION
# 999      DALR9GDAQ            1                ROUTINE INSPECTION
#
# [1000 rows x 21 columns]

# %%
# Drop geocoded_column from Inspections DataFrame becaus it is hashed.
inspections_df = inspections_df.drop(columns = ["geocoded_column"])
inspections_df
# Out:
#                activity_date employee_id  \
# 0    2018-09-10T00:00:00.000   EE0000495
# 1    2018-07-19T00:00:00.000   EE0001130
# 2    2018-08-15T00:00:00.000   EE0000500
# 3    2018-07-16T00:00:00.000   EE0000045
# 4    2018-09-07T00:00:00.000   EE0000526
# 5    2018-09-18T00:00:00.000   EE0000437
# 6    2018-09-18T00:00:00.000   EE0001121
# 7    2018-07-17T00:00:00.000   EE0000399
# 8    2018-07-12T00:00:00.000   EE0000946
# 9    2018-08-24T00:00:00.000   EE0001002
# 10   2018-09-18T00:00:00.000   EE0000025
# 11   2018-09-15T00:00:00.000   EE0000633
# 12   2018-08-01T00:00:00.000   EE0000997
# 13   2018-08-03T00:00:00.000   EE0000011
# 14   2018-08-09T00:00:00.000   EE0001098
# 15   2018-08-02T00:00:00.000   EE0000847
# 16   2018-09-12T00:00:00.000   EE0000161
# 17   2018-08-21T00:00:00.000   EE0000338
# 18   2018-08-29T00:00:00.000   EE0000854
# 19   2018-09-04T00:00:00.000   EE0000483
# 20   2018-07-19T00:00:00.000   EE0000360
# 21   2018-08-14T00:00:00.000   EE0000742
# 22   2017-09-01T00:00:00.000   EE0000503
# 23   2018-07-24T00:00:00.000   EE0000740
# 24   2018-09-06T00:00:00.000   EE0000318
# 25   2018-08-15T00:00:00.000   EE0000161
# 26   2018-08-02T00:00:00.000   EE0000924
# 27   2018-07-17T00:00:00.000   EE0000873
# 28   2018-07-18T00:00:00.000   EE0000495
# 29   2018-09-14T00:00:00.000   EE0001164
# ..                       ...         ...
# 970  2018-09-04T00:00:00.000   EE0001124
# 971  2018-07-17T00:00:00.000   EE0000965
# 972  2018-07-27T00:00:00.000   EE0000526
# 973  2018-08-01T00:00:00.000   EE0000946
# 974  2018-08-28T00:00:00.000   EE0000188
# 975  2018-09-18T00:00:00.000   EE0000031
# 976  2018-07-13T00:00:00.000   EE0000721
# 977  2018-09-05T00:00:00.000   EE0001120
# 978  2018-07-16T00:00:00.000   EE0001011
# 979  2018-09-04T00:00:00.000   EE0000965
# 980  2018-07-25T00:00:00.000   EE0000500
# 981  2018-07-13T00:00:00.000   EE0000709
# 982  2018-07-27T00:00:00.000   EE0000578
# 983  2018-07-20T00:00:00.000   EE0000731
# 984  2018-08-08T00:00:00.000   EE0000355
# 985  2018-08-28T00:00:00.000   EE0000126
# 986  2018-08-24T00:00:00.000   EE0000727
# 987  2018-09-13T00:00:00.000   EE0000031
# 988  2018-09-13T00:00:00.000   EE0000957
# 989  2018-07-19T00:00:00.000   EE0001003
# 990  2018-08-15T00:00:00.000   EE0000506
# 991  2018-08-10T00:00:00.000   EE0000145
# 992  2018-08-24T00:00:00.000   EE0001073
# 993  2018-08-20T00:00:00.000   EE0001111
# 994  2018-09-19T00:00:00.000   EE0001167
# 995  2018-08-09T00:00:00.000   EE0001003
# 996  2018-09-12T00:00:00.000   EE0000999
# 997  2018-09-07T00:00:00.000   EE0000520
# 998  2018-08-02T00:00:00.000   EE0000799
# 999  2018-07-18T00:00:00.000   EE0000382
#
#                               facility_address          facility_city  \
# 0                          203 W OLIVE AVE # C                BURBANK
# 1    1030 W MARTIN LUTHER KING JR BLVD STE 108            LOS ANGELES
# 2                               1515 E AMAR RD            WEST COVINA
# 3                            13560 ROSCOE BLVD          PANORAMA CITY
# 4                              29002 AGOURA RD           AGOURA HILLS
# 5                            5725 FLORENCE AVE           BELL GARDENS
# 6                   11540 HAWTHORNE BLVD STE A              HAWTHORNE
# 7                             6032 RESEDA BLVD                TARZANA
# 8                           2530 GLENDALE BLVD            LOS ANGELES
# 9                             9755 CULVER BLVD            CULVER CITY
# 10                          730 N VICTORY BLVD                BURBANK
# 11                          3939 S FIGUEROA ST            LOS ANGELES
# 12                              1213 S SOTO ST            LOS ANGELES
# 13                         13839 FOOTHILL BLVD                 SYLMAR
# 14                           9319 S ALAMEDA ST            LOS ANGELES
# 15                         16836 DEVONSHIRE ST          GRANADA HILLS
# 16                         14562 E VALLEY BLVD              LA PUENTE
# 17              13050 SAN VICENTE BLVD STE 114            LOS ANGELES
# 18                               3451 W 6TH ST            LOS ANGELES
# 19                     26238 BOUQUET CANYON RD          SANTA CLARITA
# 20                        319 E 2ND ST STE 206            LOS ANGELES
# 21                             659 E ARROW HWY                  AZUSA
# 22                       15234 E WHITTIER BLVD               WHITTIER
# 23                             1820 MARENGO ST            LOS ANGELES
# 24                        1320 W GLENOAKS BLVD               GLENDALE
# 25                               13925 AMAR RD              LA PUENTE
# 26                              340 N MAPLE DR          BEVERLY HILLS
# 27                            8720 SUNSET BLVD         WEST HOLLYWOOD
# 28                        111 RAGING WATERS DR              SAN DIMAS
# 29                      4716 1/2 ADMIRALTY WAY         MARINA DEL REY
# ..                                         ...                    ...
# 970                          631 FOOTHILL BLVD   LA CANADA FLINTRIDGE
# 971                        1774 E FLORENCE AVE            LOS ANGELES
# 972                              5013 KANAN RD           AGOURA HILLS
# 973                         2366 GLENDALE BLVD            LOS ANGELES
# 974                      11725 GARVEY AVE # 6C               EL MONTE
# 975                          7918 NORWALK BLVD               WHITTIER
# 976                         4228 S AVALON BLVD            LOS ANGELES
# 977                500 N ATLANTIC BLVD STE 166          MONTEREY PARK
# 978                        812 N EVERGREEN AVE            LOS ANGELES
# 979                        2112 E FLORENCE AVE            WALNUT PARK
# 980                      3648 S NOGALES ST # C            WEST COVINA
# 981                        5269 HOLLYWOOD BLVD            LOS ANGELES
# 982                         20060 VENTURA BLVD         WOODLAND HILLS
# 983                      1664 W SEPULVEDA BLVD            HARBOR CITY
# 984                     200 S SAN GABRIEL BLVD            SAN GABRIEL
# 985                            7 PENINSULA CTR  ROLLING HILLS ESTATES
# 986                     11684 SAN VICENTE BLVD            LOS ANGELES
# 987                     5331 S WORKMAN MILL RD               WHITTIER
# 988                           150 S BEVERLY DR          BEVERLY HILLS
# 989                     5311 SANTA MONICA BLVD            LOS ANGELES
# 990                           225 LINCOLN BLVD                 VENICE
# 991                        5500 N WOODRUFF AVE               LAKEWOOD
# 992                        10727 S CENTRAL AVE            LOS ANGELES
# 993                      1453 W MANCHESTER AVE            LOS ANGELES
# 994                          330 N ALVARADO ST            LOS ANGELES
# 995                           5059 MELROSE AVE            LOS ANGELES
# 996                             2360 PICO BLVD           SANTA MONICA
# 997                         5947 FALLBROOK AVE         WOODLAND HILLS
# 998                            8451 BEVERLY RD            PICO RIVERA
# 999                        1003 S GLENDORA AVE            WEST COVINA
#
#     facility_id                     facility_name facility_state facility_zip  \
# 0     FA0242046              SERVERY- NICKELODEON             CA        91502
# 1     FA0252769                   TOMS JR BURGERS             CA   90037-1867
# 2     FA0011237                    DJ BIBINGKAHAN             CA        91792
# 3     FA0061073                     DOROSE LIQUOR             CA        91402
# 4     FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE             CA        91301
# 5     FA0158101                 MCDONALD'S #10681             CA        90201
# 6     FA0264511          HULI HULI HAWAIIAN GRILL             CA        90250
# 7     FA0011473                 BURRITOS EL CHAVO             CA        91356
# 8     FA0017398                      CVS/PHARMACY             CA        90039
# 9     FA0138817                         CAFE VIDA             CA        90232
# 10    FA0004911                BARRAGAN'S MEXICAN             CA        91502
# 11    FA0258944                              LAFC             CA        90037
# 12    FA0054833           WINCHELL'S DONUTS #9517             CA        90023
# 13    FA0008027                BAMBINO'S PIZZERIA             CA        91342
# 14    FA0177577                         GI LIQUOR             CA        90002
# 15    FA0242453                PANERA BREAD #4241             CA        91344
# 16    FA0034962                   LA PUENTE SHELL             CA        91746
# 17    FA0034788                 LE PAIN QUOTIDIEN             CA        90049
# 18    FA0163047                            ESCALA             CA        90020
# 19    FA0240044                        MY HOT POT             CA        91350
# 20    FA0041946               ZENCU SUSHI & GRILL             CA        90012
# 21    FA0003277     ALDOLINO'S ITALIAN RESTAURANT             CA        91740
# 22    FA0005024                    BASKIN ROBBINS             CA        90603
# 23    FA0037462                    MARIA'S BAKERY             CA        90033
# 24    FA0020486      LA BANQUET S -GLENOAKS BALLR             CA        91201
# 25    FA0058380                   BIG SAVER FOODS             CA        91746
# 26    FA0005479         BEVERLY HILLS TENNIS CLUB             CA        90210
# 27    FA0179818                   TOCAYA ORGANICA             CA        90069
# 28    FA0140146                     RAGING WATERS             CA   91773-3928
# 29    FA0165647                    KREATION JUICE             CA        90292
# ..          ...                               ...            ...          ...
# 970   FA0035863                 LOS GRINGOS LOCOS             CA        91011
# 971   FA0225945                 BOYS BURGERS NO.1             CA        90001
# 972   FA0165525                      POPPED FRESH             CA        91301
# 973   FA0046135                   RED LION TAVERN             CA        90039
# 974   FA0138042            LA VICTORIA RESTAURANT             CA        91732
# 975   FA0025761                          GNC 8086             CA        90606
# 976   FA0010013              CORONADO MEAT MARKET             CA        90011
# 977   FA0262281                          HULAFISH             CA   91754-7735
# 978   FA0021493             EL TEPEYAC RESTAURANT             CA        90063
# 979   FA0238959               COLD STONE CREAMERY             CA   90255-5617
# 980   FA0203670                      JIN TEAHOUSE             CA        91792
# 981   FA0261457                   PA ORD NOODLE 3             CA        90027
# 982   FA0252479          AFC SUSHI @ RALPHS #0070             CA        91364
# 983   FA0071295          SUBWAY SANDWICH & SALADS             CA        90710
# 984   FA0262726           TASTY CHOICE RESTAURANT             CA        91776
# 985   FA0028066                   PAVILIONS #2233             CA        90274
# 986   FA0027070            HARRY'S WINE & SPIRITS             CA        90049
# 987   FA0061355           EL CAMINO MEXICAN GRILL             CA        90601
# 988   FA0028394                  PICCOLO PARADISO             CA        90212
# 989   FA0019185                       JONS MARKET             CA        90029
# 990   FA0055176            WHOLE FOODS MARKET #43             CA        90291
# 991   FA0073623                        VONS #2209             CA        90713
# 992   FA0224903                    EXPRESS BURGER             CA        90059
# 993   FA0006575                 BURGER KING #1346             CA        90047
# 994   FA0012496                     EL POLLO LOCO             CA        90026
# 995   FA0163076                  PRODUCE FOR LESS             CA   90038-4115
# 996   FA0055749                   YOSHINOYA #1128             CA        90405
# 997   FA0001328            JIM'S FALLBROOK MARKET             CA        91367
# 998   FA0166889                     RICK'S MARKET             CA   90660-2200
# 999   FA0261857           WT HIBACHI GRILL BUFFET             CA        91790
#
#     grade   owner_id                              owner_name  \
# 0       A  OW0105348             GUCKENHEIMER SERVICES, LLC.
# 1       A  OW0246461                      ANASTACIOS POLITIS
# 2       A  OW0010130              DJ BIBINGKAHAN CORPORATION
# 3       A  OW0020051                          KULWINDER KAUR
# 4       A  OW0246329                           JUAN C OROZCO
# 5       A  OW0123199                 REDONDO ENTERPRISES LLC
# 6       A  OW0255633                      LH HAWAII BBQ INC.
# 7       A  OW0026553                          OCHOA,SALVADOR
# 8       A  OW0012926                GARFIELD BEACH CVS, LLC.
# 9       A  OW0102114                     CCM CREATIONS, INC.
# 10      A  OW0004005               BARRAGAN'S RESTAURANT INC
# 11      A  OW0251049                      LEGENDS SPORTS LLC
# 12      A  OW0040037                YUM YUM DONUT SHOPS INC.
# 13      A  OW0014320                    GUTIERREZ, HECTOR J.
# 14      A  OW0183492                       JARNAIL & B INC .
# 15      A  OW0030197                         RISEN BREAD LLC
# 16      A  OW0019185                              KIM, BRIAN
# 17      A  OW0028928                     PQ SAN VICENTE INC.
# 18      B  OW0126723                             WOOLEE INC.
# 19      A  OW0236213                          MY HOT POT LLC
# 20      A  OW0018554                            KATYAYA, INC
# 21      A  OW0040162                         ZARAZUA GABRIEL
# 22      A  OW0029792                  RAZZAK, MOHAMMED QADER
# 23      A  OW0021305                              LEE, MARIA
# 24      A  OW0031821                        SARKISSIAN, VREJ
# 25      A  OW0036820               UKA'S BIG SAVER FOODS INC
# 26      A  OW0004579            BEVERLY HILLS TENNIS CLUB IN
# 27      A  OW0185308                          EDL SUNSET LLC
# 28      A  OW0011794                  FESTIVAL FUN PARKS LLC
# 29      A  OW0128889           KREATION & ABBOTT KINNEY, INC
# ..    ...        ...                                     ...
# 970     A  OW0022289                   LOS GRINGOS LOCOS LLC
# 971     A  OW0230147                      PACIFIC BOYS, INC.
# 972     A  OW0128781                        POPPED FRESH LLC
# 973     A  OW0029744                     RAUDONAS LIUTAS INC
# 974     A  OW0101449                           PEREZ, OFELIA
# 975     A  OW0026051                         NICK & ERIC INC
# 976     A  OW0008817                          CORONADO, JOSE
# 977     A  OW0253763                       KALEY & CO., INC.
# 978     A  OW0010901                          EL TEPEYAC INC
# 979     A  OW0235345                       KANONI FAMILY INC
# 980     A  OW0208819                            JIN TEAHOUSE
# 981     A  OW0253085                       SIRIWAN RAJPRADIT
# 982     A  OW0001761  ADVANCED FRESH CONCEPTS FRANCHISE CORP
# 983     A  OW0039322                             WTC III INC
# 984     A  OW0254185                  MIMI TASTY CHOICE INC.
# 985     A  OW0038181                 THE VONS COMPANIES INC.
# 986     A  OW0014909                  HARRY'S WINE & SPIRITS
# 987     A  OW0037964                        VILLANUEVA, ALMA
# 988     A  OW0006226                CARNIVALE RESTAURANT INC
# 989     A  OW0004431                   BERBERIAN ENTERPRISES
# 990     A  OW0038850                WHOLE FOODS MARKET, INC.
# 991     A  OW0038181                 THE VONS COMPANIES INC.
# 992     C  OW0229380                          EXPRESS BURGER
# 993     A  OW0024301            METRO MANAGEMENT SYSTIEMS IN
# 994     A  OW0010868                     EL POLLO LOCO, INC.
# 995     B  OW0126750                           RUPINDER KAUR
# 996     A  OW0101581                 YOSHINOYA AMERICA, INC.
# 997     A  OW0023980             MCQUAID,MICHAEL AND PATRICK
# 998     A  OW0129976                           OSAMA IBRAHIM
# 999     C  OW0253393           WT HIBACHI GRILL BUFFET, INC.
#
#                               pe_description  program_element_pe  \
# 0         RESTAURANT (31-60) SEATS HIGH RISK                1635
# 1          RESTAURANT (0-30) SEATS HIGH RISK                1632
# 2      RESTAURANT (0-30) SEATS MODERATE RISK                1631
# 3      FOOD MKT RETAIL (1-1,999 SF) LOW RISK                1610
# 4        RESTAURANT (151 + ) SEATS HIGH RISK                1641
# 5    RESTAURANT (61-150) SEATS MODERATE RISK                1637
# 6          RESTAURANT (0-30) SEATS HIGH RISK                1632
# 7         RESTAURANT (31-60) SEATS HIGH RISK                1635
# 8       FOOD MKT RETAIL (2,000+ SF) LOW RISK                1613
# 9         RESTAURANT (31-60) SEATS HIGH RISK                1635
# 10       RESTAURANT (151 + ) SEATS HIGH RISK                1641
# 11          RESTAURANT (0-30) SEATS LOW RISK                1630
# 12     RESTAURANT (0-30) SEATS MODERATE RISK                1631
# 13    RESTAURANT (31-60) SEATS MODERATE RISK                1634
# 14     FOOD MKT RETAIL (1-1,999 SF) LOW RISK                1610
# 15       RESTAURANT (61-150) SEATS HIGH RISK                1638
# 16     FOOD MKT RETAIL (1-1,999 SF) LOW RISK                1610
# 17       RESTAURANT (61-150) SEATS HIGH RISK                1638
# 18       RESTAURANT (61-150) SEATS HIGH RISK                1638
# 19        RESTAURANT (31-60) SEATS HIGH RISK                1635
# 20       RESTAURANT (61-150) SEATS HIGH RISK                1638
# 21       RESTAURANT (61-150) SEATS HIGH RISK                1638
# 22     RESTAURANT (0-30) SEATS MODERATE RISK                1630
# 23     RESTAURANT (0-30) SEATS MODERATE RISK                1631
# 24       RESTAURANT (151 + ) SEATS HIGH RISK                1641
# 25    FOOD MKT RETAIL (1-1,999 SF) HIGH RISK                1612
# 26       RESTAURANT (61-150) SEATS HIGH RISK                1638
# 27       RESTAURANT (151 + ) SEATS HIGH RISK                1641
# 28     RESTAURANT (0-30) SEATS MODERATE RISK                1631
# 29     FOOD MKT RETAIL (1-1,999 SF) LOW RISK                1610
# ..                                       ...                 ...
# 970      RESTAURANT (61-150) SEATS HIGH RISK                1638
# 971        RESTAURANT (0-30) SEATS HIGH RISK                1632
# 972         RESTAURANT (0-30) SEATS LOW RISK                1630
# 973      RESTAURANT (61-150) SEATS HIGH RISK                1638
# 974       RESTAURANT (31-60) SEATS HIGH RISK                1635
# 975    FOOD MKT RETAIL (1-1,999 SF) LOW RISK                1610
# 976    FOOD MKT RETAIL (2,000+ SF) HIGH RISK                1615
# 977       RESTAURANT (31-60) SEATS HIGH RISK                1635
# 978      RESTAURANT (61-150) SEATS HIGH RISK                1638
# 979         RESTAURANT (0-30) SEATS LOW RISK                1630
# 980        RESTAURANT (0-30) SEATS HIGH RISK                1632
# 981        RESTAURANT (0-30) SEATS HIGH RISK                1632
# 982        RESTAURANT (0-30) SEATS HIGH RISK                1632
# 983    RESTAURANT (0-30) SEATS MODERATE RISK                1631
# 984      RESTAURANT (61-150) SEATS HIGH RISK                1638
# 985   FOOD MKT RETAIL (1-1,999 SF) HIGH RISK                1612
# 986    FOOD MKT RETAIL (1-1,999 SF) LOW RISK                1610
# 987       RESTAURANT (31-60) SEATS HIGH RISK                1635
# 988      RESTAURANT (61-150) SEATS HIGH RISK                1638
# 989     FOOD MKT RETAIL (2,000+ SF) LOW RISK                1615
# 990        RESTAURANT (0-30) SEATS HIGH RISK                1632
# 991     FOOD MKT RETAIL (2,000+ SF) LOW RISK                1613
# 992       RESTAURANT (31-60) SEATS HIGH RISK                1635
# 993  RESTAURANT (61-150) SEATS MODERATE RISK                1637
# 994      RESTAURANT (61-150) SEATS HIGH RISK                1638
# 995    FOOD MKT RETAIL (2,000+ SF) HIGH RISK                1615
# 996        RESTAURANT (0-30) SEATS HIGH RISK                1632
# 997    FOOD MKT RETAIL (2,000+ SF) HIGH RISK                1615
# 998    FOOD MKT RETAIL (1-1,999 SF) LOW RISK                1610
# 999      RESTAURANT (151 + ) SEATS HIGH RISK                1641
#
#                          program_name program_status  record_id  score  \
# 0                SERVERY- NICKELODEON         ACTIVE  PR0190194     96
# 1                     TOMS JR BURGERS         ACTIVE  PR0202127     98
# 2             DJ BIBINGKAHAN BAKESHOP         ACTIVE  PR0035416     98
# 3                       DOROSE LIQUOR         ACTIVE  PR0027907     91
# 4    MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE  PR0201914     90
# 5                   MCDONALD'S #10681         ACTIVE  PR0146191     91
# 6            HULI HULI HAWAIIAN GRILL         ACTIVE  PR0215618     90
# 7                   BURRITOS EL CHAVO         ACTIVE  PR0005803     96
# 8                        CVS/PHARMACY         ACTIVE  PR0027636     93
# 9                           CAFE VIDA         ACTIVE  PR0123185     91
# 10                 BARRAGAN'S MEXICAN         ACTIVE  PR0023156     98
# 11   LAFC - 04.02.04 / CITY VIEW CLUB         ACTIVE  PR0209031     96
# 12            WINCHELL'S DONUTS #9517         ACTIVE  PR0015463     92
# 13                  BAMBINO'S PIZERIA         ACTIVE  PR0002731     91
# 14                          GI LIQUOR         ACTIVE  PR0170601     97
# 15                 PANERA BREAD #4241         ACTIVE  PR0190624     96
# 16                    LA PUENTE SHELL         ACTIVE  PR0028006     96
# 17                  LE PAIN QUOTIDIEN         ACTIVE  PR0017456     93
# 18                         CANDELARIA         ACTIVE  PR0151221     83
# 19                         MY HOT POT         ACTIVE  PR0188048     95
# 20                ZENCU SUSHI & GRILL         ACTIVE  PR0044601     92
# 21      ALDOLINO'S ITALIAN RESTAURANT         ACTIVE  PR0032442     95
# 22                     BASKIN ROBBINS         ACTIVE  PR0029297     92
# 23                     MARIA'S BAKERY         ACTIVE  PR0013043     90
# 24       LA BANQUET S -GLENOAKS BALLR         ACTIVE  PR0000683     93
# 25                    BIG SAVER FOODS         ACTIVE  PR0011628     92
# 26          BEVERLY HILLS TENNIS CLUB         ACTIVE  PR0007571     97
# 27                    TOCAYA ORGANICA         ACTIVE  PR0173474     91
# 28             PIPELINE PIZZA EXPRESS         ACTIVE  PR0021024     99
# 29                     KREATION JUICE         ACTIVE  PR0153978    100
# ..                                ...            ...        ...    ...
# 970                 LOS GRINGOS LOCOS         ACTIVE  PR0018093     93
# 971                 BOYS BURGERS NO.1         ACTIVE  PR0181264     91
# 972                      POPPED FRESH         ACTIVE  PR0153854     99
# 973                   RED LION TAVERN         ACTIVE  PR0015567     97
# 974            LA VICTORIA RESTAURANT         ACTIVE  PR0122271     90
# 975                          GNC 8086         ACTIVE  PR0008982     96
# 976              CORONADO MEAT MARKET         ACTIVE  PR0045354     91
# 977                          HULAFISH       INACTIVE  PR0212978     91
# 978             EL TEPEYAC RESTAURANT         ACTIVE  PR0005589    100
# 979               COLD STONE CREAMERY         ACTIVE  PR0186907     97
# 980                      JIN TEAHOUSE         ACTIVE  PR0176071     90
# 981                   PA ORD NOODLE 3         ACTIVE  PR0212027     92
# 982          AFC SUSHI @ RALPHS #0070         ACTIVE  PR0201752     96
# 983          SUBWAY SANDWICH & SALADS         ACTIVE  PR0009391     97
# 984           TASTY CHOICE RESTAURANT         ACTIVE  PR0213513     91
# 985       PAVILIONS #2233 - MEAT DEPT         ACTIVE  PR0033695     97
# 986            HARRY'S WINE & SPIRITS         ACTIVE  PR0041615     97
# 987           EL CAMINO MEXICAN GRILL         ACTIVE  PR0030814     96
# 988                 PICCOLO PARADISCO         ACTIVE  PR0039984     93
# 989                   JON'S MARKET #7         ACTIVE  PR0043069     97
# 990      WHOLEFOODS DELI/PREPARED FOO         ACTIVE  PR0027038     93
# 991                        VONS #2209         ACTIVE  PR0024692     95
# 992                    EXPRESS BURGER       INACTIVE  PR0180180     77
# 993                 BURGER KING #1346         ACTIVE  PR0010143     93
# 994                     EL POLLO LOCO         ACTIVE  PR0015865     93
# 995                  PRODUCE FOR LESS         ACTIVE  PR0151246     80
# 996          YOSHINOYA BEEF BOWL REST         ACTIVE  PR0000189     93
# 997            JIM'S FALLBROOK MARKET         ACTIVE  PR0026439     96
# 998                     RICK'S MARKET         ACTIVE  PR0157225     92
# 999           WT HIBACHI GRILL BUFFET         ACTIVE  PR0212492     75
#
#     serial_number  service_code               service_description
# 0       DARRFUZBW             1                ROUTINE INSPECTION
# 1       DA0XQVMTN             1                ROUTINE INSPECTION
# 2       DAMPOJNY8             1                ROUTINE INSPECTION
# 3       DAUTU3DPD             1                ROUTINE INSPECTION
# 4       DAUEU4NGF             1                ROUTINE INSPECTION
# 5       DARQIUA45             1                ROUTINE INSPECTION
# 6       DA0JE0XXO             1                ROUTINE INSPECTION
# 7       DAGKKNDCV             1                ROUTINE INSPECTION
# 8       DACOHF2H4             1                ROUTINE INSPECTION
# 9       DACIDHL0U           401  OWNER INITIATED ROUTINE INSPECT.
# 10      DABWNUI3O             1                ROUTINE INSPECTION
# 11      DA30IVVSL             1                ROUTINE INSPECTION
# 12      DAN40VEF6             1                ROUTINE INSPECTION
# 13      DAIPLB050             1                ROUTINE INSPECTION
# 14      DAQHC9UMM             1                ROUTINE INSPECTION
# 15      DAERIHGIJ             1                ROUTINE INSPECTION
# 16      DAR1E1EVY             1                ROUTINE INSPECTION
# 17      DA0XCDE0H             1                ROUTINE INSPECTION
# 18      DAPCQ9VAR             1                ROUTINE INSPECTION
# 19      DAXHN6FYF             1                ROUTINE INSPECTION
# 20      DAJNK3M9V             1                ROUTINE INSPECTION
# 21      DA0RAQH09             1                ROUTINE INSPECTION
# 22      DADJBKMVN             1                ROUTINE INSPECTION
# 23      DA3ETVYNG             1                ROUTINE INSPECTION
# 24      DAGJFPDYA             1                ROUTINE INSPECTION
# 25      DA2NXQSSE             1                ROUTINE INSPECTION
# 26      DAWZLOB5R             1                ROUTINE INSPECTION
# 27      DATWYNKMQ             1                ROUTINE INSPECTION
# 28      DAYAKUS0H             1                ROUTINE INSPECTION
# 29      DAU2N88BR             1                ROUTINE INSPECTION
# ..            ...           ...                               ...
# 970     DAWCXSXTP             1                ROUTINE INSPECTION
# 971     DA3X7RIM0             1                ROUTINE INSPECTION
# 972     DAGB2ERHE             1                ROUTINE INSPECTION
# 973     DANLXHVRZ             1                ROUTINE INSPECTION
# 974     DA1ALMGT4             1                ROUTINE INSPECTION
# 975     DA0V5H0O6             1                ROUTINE INSPECTION
# 976     DA0UDKRBV             1                ROUTINE INSPECTION
# 977     DA2Q3CNEB             1                ROUTINE INSPECTION
# 978     DACBXMHT5             1                ROUTINE INSPECTION
# 979     DALDRUZT9             1                ROUTINE INSPECTION
# 980     DAYAP0NXQ             1                ROUTINE INSPECTION
# 981     DAMANYCBV             1                ROUTINE INSPECTION
# 982     DABAZWHWG             1                ROUTINE INSPECTION
# 983     DA4R85GBE             1                ROUTINE INSPECTION
# 984     DAU5VW1KS             1                ROUTINE INSPECTION
# 985     DAKM0ZZWW             1                ROUTINE INSPECTION
# 986     DATFCCYVJ             1                ROUTINE INSPECTION
# 987     DAHADERAA             1                ROUTINE INSPECTION
# 988     DABAEMSTR             1                ROUTINE INSPECTION
# 989     DAMGTCSOF             1                ROUTINE INSPECTION
# 990     DA42OUUK8             1                ROUTINE INSPECTION
# 991     DAPPVZ2GZ             1                ROUTINE INSPECTION
# 992     DA3LYP1JF             1                ROUTINE INSPECTION
# 993     DA0JFUP6U             1                ROUTINE INSPECTION
# 994     DAVZSS2JO             1                ROUTINE INSPECTION
# 995     DAYNOBKAY             1                ROUTINE INSPECTION
# 996     DAX6EQH2R             1                ROUTINE INSPECTION
# 997     DAUNLUNBV             1                ROUTINE INSPECTION
# 998     DANUGOBDL             1                ROUTINE INSPECTION
# 999     DALR9GDAQ             1                ROUTINE INSPECTION
#
# [1000 rows x 20 columns]

# %%
# Check the number of unique values in each column
inspections_df.nunique()
# Out:
# activity_date            56
# employee_id             227
# facility_address        989
# facility_city           114
# facility_id             992
# facility_name           959
# facility_state            1
# facility_zip            303
# grade                     3
# owner_id                902
# owner_name              900
# pe_description           19
# program_element_pe       18
# program_name            963
# program_status            2
# record_id               999
# score                    23
# serial_number          1000
# service_code              2
# service_description       2
# dtype: int64

# %%
# Cast XXXXX column from object to integer
#df.<column_name> = df.<column_name>.astype('int64')

# %%
# Get dataset of health dataset using Los Angeles County API
community_df = pd.read_csv("./Resources/LOS_ANGELES_COUNTY_RESTAURANT_AND_MARKET_INSPECTIONS.csv")

# %%
# Create Inspections DataFrame
inspections_df = pd.DataFrame(inspections_dataset)
inspections_df.head()
