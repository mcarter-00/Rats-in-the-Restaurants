# %% [markdown]
# ## Rats in the Restaurant - Data Cleaning and Transformation
# #### County of Los Angeles Open Data Source
# * Dataset #1: https://data.lacounty.gov/Health/LOS-ANGELES-COUNTY-RESTAURANT-AND-MARKET-INSPECTIO/6ni6-h5kp
# * Dataset #2: https://data.lacounty.gov/Health/LOS-ANGELES-COUNTY-RESTAURANT-AND-MARKET-VIOLATION/8jyd-4pv9
# * Dataset #3: https://data.lacounty.gov/Health/Los-Angeles-County-City-and-Community-Health-Profi/capb-kusk

# %%
# Import dependencies
import pandas as pd
import re
import datetime as dt

# %%
# Get datasets
inspections_dataset = pd.read_csv("./Resources/LOS_ANGELES_COUNTY_RESTAURANT_AND_MARKET_INSPECTIONS.csv")
violations_dataset = pd.read_csv("./Resources/LOS_ANGELES_COUNTY_RESTAURANT_AND_MARKET_VIOLATIONS.csv")
communityhealth_dataset = pd.read_csv("./Resources/Los_Angeles_County_City_and_Community_Health_Profiles_2018.csv")

# %%
# Expand output display to view all
pd.set_option('display.max_columns', 999)

# %%
# Create Inspections DF
inspections_df = pd.DataFrame(inspections_dataset)
inspections_df.head()
# Out:
#   ACTIVITY DATE   OWNER ID                   OWNER NAME FACILITY ID  \
# 0    09/10/2018  OW0105348  GUCKENHEIMER SERVICES, LLC.   FA0242046
# 1    07/19/2018  OW0246461           ANASTACIOS POLITIS   FA0252769
# 2    08/15/2018  OW0010130   DJ BIBINGKAHAN CORPORATION   FA0011237
# 3    07/16/2018  OW0020051               KULWINDER KAUR   FA0061073
# 4    09/07/2018  OW0246329                JUAN C OROZCO   FA0252595
#
#                       FACILITY NAME  RECORD ID  \
# 0              SERVERY- NICKELODEON  PR0190194
# 1                   TOMS JR BURGERS  PR0202127
# 2                    DJ BIBINGKAHAN  PR0035416
# 3                     DOROSE LIQUOR  PR0027907
# 4  MEJICO GRILL AND TEQUILLA LOUNGE  PR0201914
#
#                        PROGRAM NAME PROGRAM STATUS  PROGRAM ELEMENT (PE)  \
# 0              SERVERY- NICKELODEON         ACTIVE                  1635
# 1                   TOMS JR BURGERS         ACTIVE                  1632
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE                  1631
# 3                     DOROSE LIQUOR         ACTIVE                  1610
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE                  1641
#
#                           PE DESCRIPTION  \
# 0     RESTAURANT (31-60) SEATS HIGH RISK
# 1      RESTAURANT (0-30) SEATS HIGH RISK
# 2  RESTAURANT (0-30) SEATS MODERATE RISK
# 3  FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 4    RESTAURANT (151 + ) SEATS HIGH RISK
#
#                             FACILITY ADDRESS  FACILITY CITY FACILITY STATE  \
# 0                        203 W OLIVE AVE # C        BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108    LOS ANGELES             CA
# 2                             1515 E AMAR RD    WEST COVINA             CA
# 3                          13560 ROSCOE BLVD  PANORAMA CITY             CA
# 4                            29002 AGOURA RD   AGOURA HILLS             CA
#
#   FACILITY ZIP  SERVICE CODE SERVICE DESCRIPTION  SCORE GRADE SERIAL NUMBER  \
# 0        91502             1  ROUTINE INSPECTION     96     A     DARRFUZBW
# 1   90037-1867             1  ROUTINE INSPECTION     98     A     DA0XQVMTN
# 2        91792             1  ROUTINE INSPECTION     98     A     DAMPOJNY8
# 3        91402             1  ROUTINE INSPECTION     91     A     DAUTU3DPD
# 4        91301             1  ROUTINE INSPECTION     90     A     DAUEU4NGF
#
#   EMPLOYEE ID                       Location
# 0   EE0000495  POINT (-118.314661 34.175253)
# 1   EE0001130  POINT (-118.292543 34.010859)
# 2   EE0000500  POINT (-117.913926 34.030964)
# 3   EE0000045  POINT (-118.428399 34.221664)
# 4   EE0000526  POINT (-118.756808 34.143452)

# %%
# Create Violations DF
violations_df = pd.DataFrame(violations_dataset)
violations_df.head()
# Out:
#   SERIAL NUMBER  VIOLATION  STATUS VIOLATION CODE  \
# 0     DA000211Z  OUT OF COMPLIANCE           F006
# 1     DA000211Z  OUT OF COMPLIANCE           F044
# 2     DA000211Z  OUT OF COMPLIANCE           F014
# 3     DA000211Z  OUT OF COMPLIANCE           F029
# 4     DA000211Z  OUT OF COMPLIANCE           F035
#
#                                VIOLATION DESCRIPTION  POINTS
# 0  # 06. Adequate handwashing facilities supplied...     2.0
# 1  # 44. Floors, walls and ceilings: properly bui...     1.0
# 2   # 14. Food contact surfaces: clean and sanitized     2.0
# 3  # 29. Toxic substances properly identified, st...     1.0
# 4  # 35. Equipment/Utensils - approved; installed...     1.0

# %%
# Create Community Health DF
community_health_df = pd.DataFrame(communityhealth_dataset)
community_health_df.head()
# Out:
#         GEONAME  Pop_Tot  Prop_18y  Prop_64y  Prop_65y+  Prop_Blk  Prop_Lat  \
# 0      Alhambra    86705    0.1831    0.6504     0.1665    0.0133    0.3435
# 1      Altadena    42525    0.2072    0.6221     0.1707    0.2374    0.2905
# 2       Arcadia    56992    0.1794    0.6389     0.1817    0.0115    0.1250
# 3         Azusa    49479    0.2507    0.6538     0.0956    0.0292    0.6838
# 4  Baldwin Park    74438    0.2623    0.6330     0.1047    0.0099    0.7934
#
#    Prop_Whi  Prop_Asi  Prop_Ami  Prop_NHO  Prop_FPL1  Prop_FPL2  Prop_forb  \
# 0    0.0913    0.5498    0.0014    0.0007     0.1303     0.3356     0.5021
# 1    0.4129    0.0553    0.0019    0.0020     0.0988     0.2281     0.2021
# 2    0.2304    0.6315    0.0014    0.0003     0.0774     0.2042     0.4877
# 3    0.1938    0.0895    0.0024    0.0013     0.1636     0.3935     0.3082
# 4    0.0432    0.1514    0.0012    0.0008     0.1591     0.4116     0.4453
#
#   Prop_Eng     LE  Prop_prsc  Prop_3rdg  Prop_edLH  Prop_edHG  Prop_edSC  \
# 0   0.2112  84.55      0.665     0.5353     0.1934     0.2280     0.2497
# 1   0.0379  82.11      0.740     0.3942     0.1050     0.1397     0.2918
# 2   0.1888  85.42      0.675     0.7927     0.0789     0.1601     0.2430
# 3   0.1156  81.16      0.439     0.3390     0.2232     0.2932     0.2873
# 4   0.1908  82.99      0.470     0.3227     0.3740     0.3170     0.1962
#
#    Prop_edCG    MHI  No_libr  Prop_empl  Prop_emsu  Prop_vote  Rte_resp  \
# 0     0.3289  53582      1.0      0.940     0.3850     0.6235    0.7706
# 1     0.4635  86050      2.0      0.920     0.7335     0.7360    1.0975
# 2     0.5180  79934      1.0      0.941     0.5691     0.6271    1.9654
# 3     0.1962  53135      1.0      0.927     0.6201     0.6569    1.0168
# 4     0.1128  51742      1.0      0.898     0.5712     0.6318    0.3406
#
#    Prop_PA  Prop_groc  Prop_60mi No_farm No_EBT Prop_foin No_CalF Rte_CalF  \
# 0   0.2731     0.5239      0.111       1      1        **  15,799   0.3300
# 1   0.3482     0.4524      0.120       1      1        **       -        -
# 2   0.2662     0.5110      0.131       0      0        **   6,638   0.1800
# 3   0.3759     0.5997      0.121       0      0    0.2006   8,868   0.5800
# 4   0.3164     0.5444      0.125       1      1    0.2531  14,206   0.7400
#
#    Prop_FRPM Prop_obse Prop_DM Rte_coin  Rte_brin  Prop_smok Rte_luca  \
# 0     0.6598    0.1358  0.1040  45.7963  125.9019     0.1272  25.4872
# 1     0.5590    0.2441  0.1358  38.3670  189.2143     0.1129  25.2189
# 2     0.2066    0.0570  0.0819  32.9547  145.2497     0.1285  22.5416
# 3     0.8060    0.2607  0.1198  31.3309  134.9485     0.1174  34.8652
# 4     0.8729    0.2652  0.1307  43.8584  110.0378     0.1045  28.2446
#
#   Rte_COPD  Rte_CVD  Prop_hbu1  Prop_hbu2  Prop_ownr  Prop_rentr  No_hless  \
# 0  21.7535  170.914      0.447      0.232      0.404       0.596        64
# 1  28.4887  211.035      0.401      0.193      0.719       0.281        58
# 2  22.0580  173.371      0.402      0.214      0.596       0.404        12
# 3  33.1891  218.754      0.474      0.240      0.527       0.473        55
# 4  31.2708  195.522      0.498      0.227      0.572       0.428       111
#
#   Prop_asth  Rte_crim Rte_hom  Rte_alco Propt_envi No_gasw Rte_te17 Rte_te19  \
# 0    0.0449       168      **        12          6       2   2.1042   9.1180
# 1    0.0915       162      **         6         62       0   3.9610   7.6173
# 2        **       146      **        19         27       2       **       **
# 3    0.0660       354       6        14         48       0   3.5084   9.2802
# 4    0.0904       391       5        10          9       0   7.3997  20.1220
#
#    Prop_LBW Rte_IMR  Prop_1stt  Prop_depr Rte_suic Rte_UOD Rte_syin  Rte_goin  \
# 0    0.0815  3.1022     0.8614     0.0523        7       3       14        66
# 1    0.0703      **     0.8859     0.1099       10       8       19       119
# 2    0.0590      **     0.8588     0.0493        9      **        8        46
# 3    0.0681      **     0.8810     0.0895        8      **       27       116
# 4    0.0856  4.1881     0.8827     0.0544       **       5       21        98
#
#   Rte_hiv  Prop_uinC  Prop_uinA Prop_duinC  Prop_duinA Propt_HPI Rte_mein  \
# 0     208     0.0598     0.2070     0.0929      0.2291      43.3       **
# 1     330     0.0333     0.1745     0.0660      0.0924      75.5     33.8
# 2      56     0.0564     0.1245     0.1232      0.1876      73.4     22.0
# 3     196     0.0708     0.2404     0.1117      0.1918      34.2       **
# 4     171     0.0582     0.3259     0.0704      0.1874      22.3       **
#
#   Rte_cein Rte_luin  Prop_fru  Prop_bev  Prop_hyp  Prop_marj Prop_HI  \
# 0       **     34.6       0.2       0.2       0.2        0.1     0.0
# 1       **     35.3       0.1       0.3       0.3        0.2     0.1
# 2       **     29.5       0.1       0.2       0.2        0.0     0.0
# 3       **     29.7       0.1       0.4       0.2        0.1     0.0
# 4       **     26.5       0.1       0.4       0.3        0.1     0.0
#
#   Prop_grad  Prop_trua
# 0       1.0        0.1
# 1       0.9        0.4
# 2       1.0        0.1
# 3       0.9        0.0
# 4       1.0        0.4

# %% [markdown]
# ### INSPECTIONS_DF DATA CLEANUP:
# #### Get data from  'PE DESCRIPTION' column
# * Type
# * No. of seats
# * Risk

# %%
#Remove all 'PE DESCRIPTION' that are not restaurants
inspections_df = inspections_df.loc[inspections_df['PE DESCRIPTION'].str.contains('RESTAURANT')]
inspections_df.head()
# Out:
#   ACTIVITY DATE   OWNER ID                   OWNER NAME FACILITY ID  \
# 0    09/10/2018  OW0105348  GUCKENHEIMER SERVICES, LLC.   FA0242046
# 1    07/19/2018  OW0246461           ANASTACIOS POLITIS   FA0252769
# 2    08/15/2018  OW0010130   DJ BIBINGKAHAN CORPORATION   FA0011237
# 4    09/07/2018  OW0246329                JUAN C OROZCO   FA0252595
# 5    09/18/2018  OW0123199      REDONDO ENTERPRISES LLC   FA0158101
#
#                       FACILITY NAME  RECORD ID  \
# 0              SERVERY- NICKELODEON  PR0190194
# 1                   TOMS JR BURGERS  PR0202127
# 2                    DJ BIBINGKAHAN  PR0035416
# 4  MEJICO GRILL AND TEQUILLA LOUNGE  PR0201914
# 5                 MCDONALD'S #10681  PR0146191
#
#                        PROGRAM NAME PROGRAM STATUS  PROGRAM ELEMENT (PE)  \
# 0              SERVERY- NICKELODEON         ACTIVE                  1635
# 1                   TOMS JR BURGERS         ACTIVE                  1632
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE                  1631
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE                  1641
# 5                 MCDONALD'S #10681         ACTIVE                  1637
#
#                             PE DESCRIPTION  \
# 0       RESTAURANT (31-60) SEATS HIGH RISK
# 1        RESTAURANT (0-30) SEATS HIGH RISK
# 2    RESTAURANT (0-30) SEATS MODERATE RISK
# 4      RESTAURANT (151 + ) SEATS HIGH RISK
# 5  RESTAURANT (61-150) SEATS MODERATE RISK
#
#                             FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY ZIP  SERVICE CODE SERVICE DESCRIPTION  SCORE GRADE SERIAL NUMBER  \
# 0        91502             1  ROUTINE INSPECTION     96     A     DARRFUZBW
# 1   90037-1867             1  ROUTINE INSPECTION     98     A     DA0XQVMTN
# 2        91792             1  ROUTINE INSPECTION     98     A     DAMPOJNY8
# 4        91301             1  ROUTINE INSPECTION     90     A     DAUEU4NGF
# 5        90201             1  ROUTINE INSPECTION     91     A     DARQIUA45
#
#   EMPLOYEE ID                       Location
# 0   EE0000495  POINT (-118.314661 34.175253)
# 1   EE0001130  POINT (-118.292543 34.010859)
# 2   EE0000500  POINT (-117.913926 34.030964)
# 4   EE0000526  POINT (-118.756808 34.143452)
# 5   EE0000437  POINT (-118.163665 33.967791)

# %%
# Get 'type', 'seats', and 'risk' from 'PE DESCRIPTION' and add them as columns to the Inspections DF
def find_est(str):
    est=re.compile('.+(?=\()')
    return est.search(str).group(0)

def find_size(str):
    size=re.compile('(?<=\().+(?=\))')
    return size.search(str).group(0)

def find_risk(str):
    return (' ').join(str.split(' ')[-2:])

inspections_df['TYPE'] = inspections_df['PE DESCRIPTION'].apply(find_est)
inspections_df['SEATS'] = inspections_df['PE DESCRIPTION'].apply(find_size)
inspections_df['RISK'] = inspections_df['PE DESCRIPTION'].apply(find_risk)

# %%
# Display DF
inspections_df.head()
# Out:
#   ACTIVITY DATE   OWNER ID                   OWNER NAME FACILITY ID  \
# 0    09/10/2018  OW0105348  GUCKENHEIMER SERVICES, LLC.   FA0242046
# 1    07/19/2018  OW0246461           ANASTACIOS POLITIS   FA0252769
# 2    08/15/2018  OW0010130   DJ BIBINGKAHAN CORPORATION   FA0011237
# 4    09/07/2018  OW0246329                JUAN C OROZCO   FA0252595
# 5    09/18/2018  OW0123199      REDONDO ENTERPRISES LLC   FA0158101
#
#                       FACILITY NAME  RECORD ID  \
# 0              SERVERY- NICKELODEON  PR0190194
# 1                   TOMS JR BURGERS  PR0202127
# 2                    DJ BIBINGKAHAN  PR0035416
# 4  MEJICO GRILL AND TEQUILLA LOUNGE  PR0201914
# 5                 MCDONALD'S #10681  PR0146191
#
#                        PROGRAM NAME PROGRAM STATUS  PROGRAM ELEMENT (PE)  \
# 0              SERVERY- NICKELODEON         ACTIVE                  1635
# 1                   TOMS JR BURGERS         ACTIVE                  1632
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE                  1631
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE                  1641
# 5                 MCDONALD'S #10681         ACTIVE                  1637
#
#                             PE DESCRIPTION  \
# 0       RESTAURANT (31-60) SEATS HIGH RISK
# 1        RESTAURANT (0-30) SEATS HIGH RISK
# 2    RESTAURANT (0-30) SEATS MODERATE RISK
# 4      RESTAURANT (151 + ) SEATS HIGH RISK
# 5  RESTAURANT (61-150) SEATS MODERATE RISK
#
#                             FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY ZIP  SERVICE CODE SERVICE DESCRIPTION  SCORE GRADE SERIAL NUMBER  \
# 0        91502             1  ROUTINE INSPECTION     96     A     DARRFUZBW
# 1   90037-1867             1  ROUTINE INSPECTION     98     A     DA0XQVMTN
# 2        91792             1  ROUTINE INSPECTION     98     A     DAMPOJNY8
# 4        91301             1  ROUTINE INSPECTION     90     A     DAUEU4NGF
# 5        90201             1  ROUTINE INSPECTION     91     A     DARQIUA45
#
#   EMPLOYEE ID                       Location         TYPE   SEATS  \
# 0   EE0000495  POINT (-118.314661 34.175253)  RESTAURANT    31-60
# 1   EE0001130  POINT (-118.292543 34.010859)  RESTAURANT     0-30
# 2   EE0000500  POINT (-117.913926 34.030964)  RESTAURANT     0-30
# 4   EE0000526  POINT (-118.756808 34.143452)  RESTAURANT   151 +
# 5   EE0000437  POINT (-118.163665 33.967791)  RESTAURANT   61-150
#
#             RISK
# 0      HIGH RISK
# 1      HIGH RISK
# 2  MODERATE RISK
# 4      HIGH RISK
# 5  MODERATE RISK

# %%
# Drop columns
inspections_df = inspections_df.drop(columns = ['OWNER ID', 
                                               'OWNER NAME',
                                               'RECORD ID', 
                                               'PROGRAM ELEMENT (PE)', 
                                               "PE DESCRIPTION", 
                                               'SERVICE CODE',
                                               'SERVICE DESCRIPTION',  
                                               'EMPLOYEE ID', 
                                               "TYPE", 
                                               "RISK"])
inspections_df.head()
# Out:
#   ACTIVITY DATE FACILITY ID                     FACILITY NAME  \
# 0    09/10/2018   FA0242046              SERVERY- NICKELODEON
# 1    07/19/2018   FA0252769                   TOMS JR BURGERS
# 2    08/15/2018   FA0011237                    DJ BIBINGKAHAN
# 4    09/07/2018   FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE
# 5    09/18/2018   FA0158101                 MCDONALD'S #10681
#
#                        PROGRAM NAME PROGRAM STATUS  \
# 0              SERVERY- NICKELODEON         ACTIVE
# 1                   TOMS JR BURGERS         ACTIVE
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# 5                 MCDONALD'S #10681         ACTIVE
#
#                             FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY ZIP  SCORE GRADE SERIAL NUMBER                       Location  \
# 0        91502     96     A     DARRFUZBW  POINT (-118.314661 34.175253)
# 1   90037-1867     98     A     DA0XQVMTN  POINT (-118.292543 34.010859)
# 2        91792     98     A     DAMPOJNY8  POINT (-117.913926 34.030964)
# 4        91301     90     A     DAUEU4NGF  POINT (-118.756808 34.143452)
# 5        90201     91     A     DARQIUA45  POINT (-118.163665 33.967791)
#
#     SEATS
# 0   31-60
# 1    0-30
# 2    0-30
# 4  151 +
# 5  61-150

# %% [markdown]
# #### Get data from 'Location' column
# * LAT
# * LNG

# %%
# Display "Location" column
inspections_df[["Location"]].head()
# Out:
#                         Location
# 0  POINT (-118.314661 34.175253)
# 1  POINT (-118.292543 34.010859)
# 2  POINT (-117.913926 34.030964)
# 4  POINT (-118.756808 34.143452)
# 5  POINT (-118.163665 33.967791)

# %%
# Split column
location_data = inspections_df["Location"].str.split(n=2, expand=True)
location_data.head()
# Out:
#        0             1           2
# 0  POINT  (-118.314661  34.175253)
# 1  POINT  (-118.292543  34.010859)
# 2  POINT  (-117.913926  34.030964)
# 4  POINT  (-118.756808  34.143452)
# 5  POINT  (-118.163665  33.967791)

# %%
# Drop column '0' aka 'POINT'
lat_lng_values = location_data.drop(columns=[0])
lat_lng_values.head()
# Out:
#               1           2
# 0  (-118.314661  34.175253)
# 1  (-118.292543  34.010859)
# 2  (-117.913926  34.030964)
# 4  (-118.756808  34.143452)
# 5  (-118.163665  33.967791)

# %%
# Get 'LAT' column
lats_split = lat_lng_values[1].str.split(pat='(', expand=True)
lat = lats_split.drop(columns=[0])
lat.columns = ['LAT']
lat.head()
# Out:
#            LAT
# 0  -118.314661
# 1  -118.292543
# 2  -117.913926
# 4  -118.756808
# 5  -118.163665

# %%
# Get 'LNG' column
lng_split = lat_lng_values[2].str.split(pat=')', expand=True)
lng = lng_split.drop(columns=[1])
lng.columns = ['LNG']
lng.head()
# Out:
#          LNG
# 0  34.175253
# 1  34.010859
# 2  34.030964
# 4  34.143452
# 5  33.967791

# %%
# Merge 'LAT' into Inspections DF
inspections_df = inspections_df.merge(lat, left_index = True, right_index = True)
inspections_df.head()
# Out:
#   ACTIVITY DATE FACILITY ID                     FACILITY NAME  \
# 0    09/10/2018   FA0242046              SERVERY- NICKELODEON
# 1    07/19/2018   FA0252769                   TOMS JR BURGERS
# 2    08/15/2018   FA0011237                    DJ BIBINGKAHAN
# 4    09/07/2018   FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE
# 5    09/18/2018   FA0158101                 MCDONALD'S #10681
#
#                        PROGRAM NAME PROGRAM STATUS  \
# 0              SERVERY- NICKELODEON         ACTIVE
# 1                   TOMS JR BURGERS         ACTIVE
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# 5                 MCDONALD'S #10681         ACTIVE
#
#                             FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY ZIP  SCORE GRADE SERIAL NUMBER                       Location  \
# 0        91502     96     A     DARRFUZBW  POINT (-118.314661 34.175253)
# 1   90037-1867     98     A     DA0XQVMTN  POINT (-118.292543 34.010859)
# 2        91792     98     A     DAMPOJNY8  POINT (-117.913926 34.030964)
# 4        91301     90     A     DAUEU4NGF  POINT (-118.756808 34.143452)
# 5        90201     91     A     DARQIUA45  POINT (-118.163665 33.967791)
#
#     SEATS          LAT
# 0   31-60  -118.314661
# 1    0-30  -118.292543
# 2    0-30  -117.913926
# 4  151 +   -118.756808
# 5  61-150  -118.163665

# %%
# Merge 'LNG' into Inspections DF
inspections_df = inspections_df.merge(lng, left_index = True, right_index = True)
inspections_df.head()
# Out:
#   ACTIVITY DATE FACILITY ID                     FACILITY NAME  \
# 0    09/10/2018   FA0242046              SERVERY- NICKELODEON
# 1    07/19/2018   FA0252769                   TOMS JR BURGERS
# 2    08/15/2018   FA0011237                    DJ BIBINGKAHAN
# 4    09/07/2018   FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE
# 5    09/18/2018   FA0158101                 MCDONALD'S #10681
#
#                        PROGRAM NAME PROGRAM STATUS  \
# 0              SERVERY- NICKELODEON         ACTIVE
# 1                   TOMS JR BURGERS         ACTIVE
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# 5                 MCDONALD'S #10681         ACTIVE
#
#                             FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY ZIP  SCORE GRADE SERIAL NUMBER                       Location  \
# 0        91502     96     A     DARRFUZBW  POINT (-118.314661 34.175253)
# 1   90037-1867     98     A     DA0XQVMTN  POINT (-118.292543 34.010859)
# 2        91792     98     A     DAMPOJNY8  POINT (-117.913926 34.030964)
# 4        91301     90     A     DAUEU4NGF  POINT (-118.756808 34.143452)
# 5        90201     91     A     DARQIUA45  POINT (-118.163665 33.967791)
#
#     SEATS          LAT        LNG
# 0   31-60  -118.314661  34.175253
# 1    0-30  -118.292543  34.010859
# 2    0-30  -117.913926  34.030964
# 4  151 +   -118.756808  34.143452
# 5  61-150  -118.163665  33.967791

# %%
# Drop 'Location' column
clean_inspections_df = inspections_df.drop(columns = ["Location"])
clean_inspections_df.head()
# Out:
#   ACTIVITY DATE FACILITY ID                     FACILITY NAME  \
# 0    09/10/2018   FA0242046              SERVERY- NICKELODEON
# 1    07/19/2018   FA0252769                   TOMS JR BURGERS
# 2    08/15/2018   FA0011237                    DJ BIBINGKAHAN
# 4    09/07/2018   FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE
# 5    09/18/2018   FA0158101                 MCDONALD'S #10681
#
#                        PROGRAM NAME PROGRAM STATUS  \
# 0              SERVERY- NICKELODEON         ACTIVE
# 1                   TOMS JR BURGERS         ACTIVE
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# 5                 MCDONALD'S #10681         ACTIVE
#
#                             FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY ZIP  SCORE GRADE SERIAL NUMBER   SEATS          LAT        LNG
# 0        91502     96     A     DARRFUZBW   31-60  -118.314661  34.175253
# 1   90037-1867     98     A     DA0XQVMTN    0-30  -118.292543  34.010859
# 2        91792     98     A     DAMPOJNY8    0-30  -117.913926  34.030964
# 4        91301     90     A     DAUEU4NGF  151 +   -118.756808  34.143452
# 5        90201     91     A     DARQIUA45  61-150  -118.163665  33.967791

# %% [markdown]
# #### Clean 'Facility Zip' data to show 5-digits only

# %%
def clean_zip(x):
    return x[:5]

clean_inspections_df['FACILITY ZIP'] = clean_inspections_df['FACILITY ZIP'].apply(clean_zip)

# Dislay DF
clean_inspections_df.head()
# Out:
#   ACTIVITY DATE FACILITY ID                     FACILITY NAME  \
# 0    09/10/2018   FA0242046              SERVERY- NICKELODEON
# 1    07/19/2018   FA0252769                   TOMS JR BURGERS
# 2    08/15/2018   FA0011237                    DJ BIBINGKAHAN
# 4    09/07/2018   FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE
# 5    09/18/2018   FA0158101                 MCDONALD'S #10681
#
#                        PROGRAM NAME PROGRAM STATUS  \
# 0              SERVERY- NICKELODEON         ACTIVE
# 1                   TOMS JR BURGERS         ACTIVE
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# 5                 MCDONALD'S #10681         ACTIVE
#
#                             FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY ZIP  SCORE GRADE SERIAL NUMBER   SEATS          LAT        LNG
# 0        91502     96     A     DARRFUZBW   31-60  -118.314661  34.175253
# 1        90037     98     A     DA0XQVMTN    0-30  -118.292543  34.010859
# 2        91792     98     A     DAMPOJNY8    0-30  -117.913926  34.030964
# 4        91301     90     A     DAUEU4NGF  151 +   -118.756808  34.143452
# 5        90201     91     A     DARQIUA45  61-150  -118.163665  33.967791

# %%
# Check null values
for column in clean_inspections_df.columns:
    print(f"Column {column} has {clean_inspections_df[column].isnull().sum()} null values.")
# Out:
# Column ACTIVITY DATE has 0 null values.
# Column FACILITY ID has 0 null values.
# Column FACILITY NAME has 0 null values.
# Column PROGRAM NAME has 0 null values.
# Column PROGRAM STATUS has 0 null values.
# Column FACILITY ADDRESS has 0 null values.
# Column FACILITY CITY has 0 null values.
# Column FACILITY STATE has 0 null values.
# Column FACILITY ZIP has 0 null values.
# Column SCORE has 0 null values.
# Column GRADE has 68 null values.
# Column SERIAL NUMBER has 0 null values.
# Column SEATS has 0 null values.
# Column LAT has 5889 null values.
# Column LNG has 5889 null values.

# %%
# Drop null values
revised_clean_inspections_df = clean_inspections_df.dropna()
revised_clean_inspections_df.head()
# Out:
#   ACTIVITY DATE FACILITY ID                     FACILITY NAME  \
# 0    09/10/2018   FA0242046              SERVERY- NICKELODEON
# 1    07/19/2018   FA0252769                   TOMS JR BURGERS
# 2    08/15/2018   FA0011237                    DJ BIBINGKAHAN
# 4    09/07/2018   FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE
# 5    09/18/2018   FA0158101                 MCDONALD'S #10681
#
#                        PROGRAM NAME PROGRAM STATUS  \
# 0              SERVERY- NICKELODEON         ACTIVE
# 1                   TOMS JR BURGERS         ACTIVE
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# 5                 MCDONALD'S #10681         ACTIVE
#
#                             FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY ZIP  SCORE GRADE SERIAL NUMBER   SEATS          LAT        LNG
# 0        91502     96     A     DARRFUZBW   31-60  -118.314661  34.175253
# 1        90037     98     A     DA0XQVMTN    0-30  -118.292543  34.010859
# 2        91792     98     A     DAMPOJNY8    0-30  -117.913926  34.030964
# 4        91301     90     A     DAUEU4NGF  151 +   -118.756808  34.143452
# 5        90201     91     A     DARQIUA45  61-150  -118.163665  33.967791

# %%
# Check #2 for null values
for column in revised_clean_inspections_df.columns:
    print(f"Column {column} has {revised_clean_inspections_df[column].isnull().sum()} null values.")
# Out:
# Column ACTIVITY DATE has 0 null values.
# Column FACILITY ID has 0 null values.
# Column FACILITY NAME has 0 null values.
# Column PROGRAM NAME has 0 null values.
# Column PROGRAM STATUS has 0 null values.
# Column FACILITY ADDRESS has 0 null values.
# Column FACILITY CITY has 0 null values.
# Column FACILITY STATE has 0 null values.
# Column FACILITY ZIP has 0 null values.
# Column SCORE has 0 null values.
# Column GRADE has 0 null values.
# Column SERIAL NUMBER has 0 null values.
# Column SEATS has 0 null values.
# Column LAT has 0 null values.
# Column LNG has 0 null values.

# %%
# Rename columns to replace 'space' with '_'
revised2_clean_inspect = revised_clean_inspections_df.rename(columns = {"ACTIVITY DATE" : "ACTIVITY_DATE",
                                                                        "FACILITY ID" : "FACILITY_ID",
                                                                        "FACILITY NAME" : "FACILITY_NAME",
                                                                        "PROGRAM NAME" : "PROGRAM_NAME",
                                                                        "PROGRAM STATUS" : "PROGRAM_STATUS",
                                                                        "FACILITY ADDRESS" : "FACILITY_ADDRESS",
                                                                        "FACILITY CITY" : "FACILITY_CITY",
                                                                        "FACILITY STATE" : "FACILITY_STATE",
                                                                        "FACILITY ZIP" : "FACILITY_ZIP",
                                                                        "SERIAL NUMBER" : "SERIAL_NUMBER"})

# Display DF
revised2_clean_inspect.head()
# Out:
#   ACTIVITY_DATE FACILITY_ID                     FACILITY_NAME  \
# 0    09/10/2018   FA0242046              SERVERY- NICKELODEON
# 1    07/19/2018   FA0252769                   TOMS JR BURGERS
# 2    08/15/2018   FA0011237                    DJ BIBINGKAHAN
# 4    09/07/2018   FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE
# 5    09/18/2018   FA0158101                 MCDONALD'S #10681
#
#                        PROGRAM_NAME PROGRAM_STATUS  \
# 0              SERVERY- NICKELODEON         ACTIVE
# 1                   TOMS JR BURGERS         ACTIVE
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# 5                 MCDONALD'S #10681         ACTIVE
#
#                             FACILITY_ADDRESS FACILITY_CITY FACILITY_STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY_ZIP  SCORE GRADE SERIAL_NUMBER   SEATS          LAT        LNG
# 0        91502     96     A     DARRFUZBW   31-60  -118.314661  34.175253
# 1        90037     98     A     DA0XQVMTN    0-30  -118.292543  34.010859
# 2        91792     98     A     DAMPOJNY8    0-30  -117.913926  34.030964
# 4        91301     90     A     DAUEU4NGF  151 +   -118.756808  34.143452
# 5        90201     91     A     DARQIUA45  61-150  -118.163665  33.967791

# %%
# Check data types
for column in revised2_clean_inspect.columns:
    print(f"Column {column} has data type -- {revised2_clean_inspect[column].dtype}.")
# Out:
# Column ACTIVITY_DATE has data type -- object.
# Column FACILITY_ID has data type -- object.
# Column FACILITY_NAME has data type -- object.
# Column PROGRAM_NAME has data type -- object.
# Column PROGRAM_STATUS has data type -- object.
# Column FACILITY_ADDRESS has data type -- object.
# Column FACILITY_CITY has data type -- object.
# Column FACILITY_STATE has data type -- object.
# Column FACILITY_ZIP has data type -- object.
# Column SCORE has data type -- int64.
# Column GRADE has data type -- object.
# Column SERIAL_NUMBER has data type -- object.
# Column SEATS has data type -- object.
# Column LAT has data type -- object.
# Column LNG has data type -- object.

# %%
# Change select column(s) to string
revised2_clean_inspect[["FACILITY_ID", 
                       "FACILITY_NAME", 
                       "PROGRAM_NAME", 
                       "PROGRAM_STATUS", 
                       "FACILITY_ADDRESS", 
                       "FACILITY_CITY", 
                       "FACILITY_STATE", 
                       "FACILITY_ZIP", 
                       "GRADE", 
                       "SERIAL_NUMBER", 
                       "SEATS"]] = revised2_clean_inspect[["FACILITY_ID", 
                                                           "FACILITY_NAME", 
                                                           "PROGRAM_NAME", 
                                                           "PROGRAM_STATUS", 
                                                           "FACILITY_ADDRESS", 
                                                           "FACILITY_CITY", 
                                                           "FACILITY_STATE", 
                                                           "FACILITY_ZIP", 
                                                           "GRADE", 
                                                           "SERIAL_NUMBER", 
                                                           "SEATS"]].astype(str)

# Check data types
revised2_clean_inspect.dtypes
# Out:
# ACTIVITY_DATE       object
# FACILITY_ID         object
# FACILITY_NAME       object
# PROGRAM_NAME        object
# PROGRAM_STATUS      object
# FACILITY_ADDRESS    object
# FACILITY_CITY       object
# FACILITY_STATE      object
# FACILITY_ZIP        object
# SCORE                int64
# GRADE               object
# SERIAL_NUMBER       object
# SEATS               object
# LAT                 object
# LNG                 object
# dtype: object

# %%
# Change select column(s) to interger
revised2_clean_inspect[["LAT", "LNG"]] = revised2_clean_inspect[["LAT", "LNG"]].astype(float)

# Check data types
revised2_clean_inspect.dtypes
# Out:
# ACTIVITY_DATE        object
# FACILITY_ID          object
# FACILITY_NAME        object
# PROGRAM_NAME         object
# PROGRAM_STATUS       object
# FACILITY_ADDRESS     object
# FACILITY_CITY        object
# FACILITY_STATE       object
# FACILITY_ZIP         object
# SCORE                 int64
# GRADE                object
# SERIAL_NUMBER        object
# SEATS                object
# LAT                 float64
# LNG                 float64
# dtype: object

# %%
# Change select column(s) to datetime
revised2_clean_inspect["ACTIVITY_DATE"] = pd.to_datetime(revised2_clean_inspect["ACTIVITY_DATE"])

# Check data types
revised2_clean_inspect.dtypes
# Out:
# ACTIVITY_DATE       datetime64[ns]
# FACILITY_ID                 object
# FACILITY_NAME               object
# PROGRAM_NAME                object
# PROGRAM_STATUS              object
# FACILITY_ADDRESS            object
# FACILITY_CITY               object
# FACILITY_STATE              object
# FACILITY_ZIP                object
# SCORE                        int64
# GRADE                       object
# SERIAL_NUMBER               object
# SEATS                       object
# LAT                        float64
# LNG                        float64
# dtype: object

# %%
# Display DF
revised2_clean_inspect.head()
# Out:
#   ACTIVITY_DATE FACILITY_ID                     FACILITY_NAME  \
# 0    2018-09-10   FA0242046              SERVERY- NICKELODEON
# 1    2018-07-19   FA0252769                   TOMS JR BURGERS
# 2    2018-08-15   FA0011237                    DJ BIBINGKAHAN
# 4    2018-09-07   FA0252595  MEJICO GRILL AND TEQUILLA LOUNGE
# 5    2018-09-18   FA0158101                 MCDONALD'S #10681
#
#                        PROGRAM_NAME PROGRAM_STATUS  \
# 0              SERVERY- NICKELODEON         ACTIVE
# 1                   TOMS JR BURGERS         ACTIVE
# 2           DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 4  MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# 5                 MCDONALD'S #10681         ACTIVE
#
#                             FACILITY_ADDRESS FACILITY_CITY FACILITY_STATE  \
# 0                        203 W OLIVE AVE # C       BURBANK             CA
# 1  1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES             CA
# 2                             1515 E AMAR RD   WEST COVINA             CA
# 4                            29002 AGOURA RD  AGOURA HILLS             CA
# 5                          5725 FLORENCE AVE  BELL GARDENS             CA
#
#   FACILITY_ZIP  SCORE GRADE SERIAL_NUMBER   SEATS         LAT        LNG
# 0        91502     96     A     DARRFUZBW   31-60 -118.314661  34.175253
# 1        90037     98     A     DA0XQVMTN    0-30 -118.292543  34.010859
# 2        91792     98     A     DAMPOJNY8    0-30 -117.913926  34.030964
# 4        91301     90     A     DAUEU4NGF  151 +  -118.756808  34.143452
# 5        90201     91     A     DARQIUA45  61-150 -118.163665  33.967791

# %%
# Check shape
revised2_clean_inspect.shape
# Out:
# (165906, 15)

# %%
# Export to csv
revised2_clean_inspect.to_csv("./Resources/Clean/clean_inspections.csv")

# %% [markdown]
# ### VIOLATIONS_DF DATA CLEANUP:

# %%
# Display DF
violations_df.head()
# Out:
#   SERIAL NUMBER  VIOLATION  STATUS VIOLATION CODE  \
# 0     DA000211Z  OUT OF COMPLIANCE           F006
# 1     DA000211Z  OUT OF COMPLIANCE           F044
# 2     DA000211Z  OUT OF COMPLIANCE           F014
# 3     DA000211Z  OUT OF COMPLIANCE           F029
# 4     DA000211Z  OUT OF COMPLIANCE           F035
#
#                                VIOLATION DESCRIPTION  POINTS
# 0  # 06. Adequate handwashing facilities supplied...     2.0
# 1  # 44. Floors, walls and ceilings: properly bui...     1.0
# 2   # 14. Food contact surfaces: clean and sanitized     2.0
# 3  # 29. Toxic substances properly identified, st...     1.0
# 4  # 35. Equipment/Utensils - approved; installed...     1.0

# %%
# Check data types
violations_df.dtypes
# Out:
# SERIAL NUMBER             object
# VIOLATION  STATUS         object
# VIOLATION CODE            object
# VIOLATION DESCRIPTION     object
# POINTS                   float64
# dtype: object

# %%
# Change all columns, but 'POINTS' to string
violations_df[["SERIAL NUMBER", 
               "VIOLATION  STATUS", 
               "VIOLATION CODE", 
               "VIOLATION DESCRIPTION"]] = violations_df[["SERIAL NUMBER", 
                                                          "VIOLATION  STATUS", 
                                                          "VIOLATION CODE", 
                                                          "VIOLATION DESCRIPTION"]].astype(str)

# Check data types
violations_df.dtypes
# Out:
# SERIAL NUMBER             object
# VIOLATION  STATUS         object
# VIOLATION CODE            object
# VIOLATION DESCRIPTION     object
# POINTS                   float64
# dtype: object

# %%
# Rename columns to replace 'space' with '_'
clean_violations_df = violations_df.rename(columns = {"SERIAL NUMBER": "SERIAL_NUMER", 
                                                      "VIOLATION  STATUS": "VIOLATION_STATUS", 
                                                      "VIOLATION CODE": "VIOLATION_CODE", 
                                                      "VIOLATION DESCRIPTION": "VIOLATION_DESCRIPTION"})

# Display DF
clean_violations_df.head()
# Out:
#   SERIAL_NUMER   VIOLATION_STATUS VIOLATION_CODE  \
# 0    DA000211Z  OUT OF COMPLIANCE           F006
# 1    DA000211Z  OUT OF COMPLIANCE           F044
# 2    DA000211Z  OUT OF COMPLIANCE           F014
# 3    DA000211Z  OUT OF COMPLIANCE           F029
# 4    DA000211Z  OUT OF COMPLIANCE           F035
#
#                                VIOLATION_DESCRIPTION  POINTS
# 0  # 06. Adequate handwashing facilities supplied...     2.0
# 1  # 44. Floors, walls and ceilings: properly bui...     1.0
# 2   # 14. Food contact surfaces: clean and sanitized     2.0
# 3  # 29. Toxic substances properly identified, st...     1.0
# 4  # 35. Equipment/Utensils - approved; installed...     1.0

# %%
# Check for null values
for column in clean_violations_df.columns:
    print(f"Column {column} has {clean_violations_df[column].isnull().sum()} null values.")
# Out:
# Column SERIAL_NUMER has 0 null values.
# Column VIOLATION_STATUS has 0 null values.
# Column VIOLATION_CODE has 0 null values.
# Column VIOLATION_DESCRIPTION has 0 null values.
# Column POINTS has 0 null values.

# %%
# Check data shape
clean_violations_df.shape
# Out:
# (971331, 5)

# %%
# Export to csv
clean_violations_df.to_csv("./Resources/Clean/clean_violations.csv")

# %% [markdown]
# ### COMMUNITY_HEALTH_DF DATA CLEANUP:

# %%
# Display DF
community_health_df.head()
# Out:
#         GEONAME  Pop_Tot  Prop_18y  Prop_64y  Prop_65y+  Prop_Blk  Prop_Lat  \
# 0      Alhambra    86705    0.1831    0.6504     0.1665    0.0133    0.3435
# 1      Altadena    42525    0.2072    0.6221     0.1707    0.2374    0.2905
# 2       Arcadia    56992    0.1794    0.6389     0.1817    0.0115    0.1250
# 3         Azusa    49479    0.2507    0.6538     0.0956    0.0292    0.6838
# 4  Baldwin Park    74438    0.2623    0.6330     0.1047    0.0099    0.7934
#
#    Prop_Whi  Prop_Asi  Prop_Ami  Prop_NHO  Prop_FPL1  Prop_FPL2  Prop_forb  \
# 0    0.0913    0.5498    0.0014    0.0007     0.1303     0.3356     0.5021
# 1    0.4129    0.0553    0.0019    0.0020     0.0988     0.2281     0.2021
# 2    0.2304    0.6315    0.0014    0.0003     0.0774     0.2042     0.4877
# 3    0.1938    0.0895    0.0024    0.0013     0.1636     0.3935     0.3082
# 4    0.0432    0.1514    0.0012    0.0008     0.1591     0.4116     0.4453
#
#   Prop_Eng     LE  Prop_prsc  Prop_3rdg  Prop_edLH  Prop_edHG  Prop_edSC  \
# 0   0.2112  84.55      0.665     0.5353     0.1934     0.2280     0.2497
# 1   0.0379  82.11      0.740     0.3942     0.1050     0.1397     0.2918
# 2   0.1888  85.42      0.675     0.7927     0.0789     0.1601     0.2430
# 3   0.1156  81.16      0.439     0.3390     0.2232     0.2932     0.2873
# 4   0.1908  82.99      0.470     0.3227     0.3740     0.3170     0.1962
#
#    Prop_edCG    MHI  No_libr  Prop_empl  Prop_emsu  Prop_vote  Rte_resp  \
# 0     0.3289  53582      1.0      0.940     0.3850     0.6235    0.7706
# 1     0.4635  86050      2.0      0.920     0.7335     0.7360    1.0975
# 2     0.5180  79934      1.0      0.941     0.5691     0.6271    1.9654
# 3     0.1962  53135      1.0      0.927     0.6201     0.6569    1.0168
# 4     0.1128  51742      1.0      0.898     0.5712     0.6318    0.3406
#
#    Prop_PA  Prop_groc  Prop_60mi No_farm No_EBT Prop_foin No_CalF Rte_CalF  \
# 0   0.2731     0.5239      0.111       1      1        **  15,799   0.3300
# 1   0.3482     0.4524      0.120       1      1        **       -        -
# 2   0.2662     0.5110      0.131       0      0        **   6,638   0.1800
# 3   0.3759     0.5997      0.121       0      0    0.2006   8,868   0.5800
# 4   0.3164     0.5444      0.125       1      1    0.2531  14,206   0.7400
#
#    Prop_FRPM Prop_obse Prop_DM Rte_coin  Rte_brin  Prop_smok Rte_luca  \
# 0     0.6598    0.1358  0.1040  45.7963  125.9019     0.1272  25.4872
# 1     0.5590    0.2441  0.1358  38.3670  189.2143     0.1129  25.2189
# 2     0.2066    0.0570  0.0819  32.9547  145.2497     0.1285  22.5416
# 3     0.8060    0.2607  0.1198  31.3309  134.9485     0.1174  34.8652
# 4     0.8729    0.2652  0.1307  43.8584  110.0378     0.1045  28.2446
#
#   Rte_COPD  Rte_CVD  Prop_hbu1  Prop_hbu2  Prop_ownr  Prop_rentr  No_hless  \
# 0  21.7535  170.914      0.447      0.232      0.404       0.596        64
# 1  28.4887  211.035      0.401      0.193      0.719       0.281        58
# 2  22.0580  173.371      0.402      0.214      0.596       0.404        12
# 3  33.1891  218.754      0.474      0.240      0.527       0.473        55
# 4  31.2708  195.522      0.498      0.227      0.572       0.428       111
#
#   Prop_asth  Rte_crim Rte_hom  Rte_alco Propt_envi No_gasw Rte_te17 Rte_te19  \
# 0    0.0449       168      **        12          6       2   2.1042   9.1180
# 1    0.0915       162      **         6         62       0   3.9610   7.6173
# 2        **       146      **        19         27       2       **       **
# 3    0.0660       354       6        14         48       0   3.5084   9.2802
# 4    0.0904       391       5        10          9       0   7.3997  20.1220
#
#    Prop_LBW Rte_IMR  Prop_1stt  Prop_depr Rte_suic Rte_UOD Rte_syin  Rte_goin  \
# 0    0.0815  3.1022     0.8614     0.0523        7       3       14        66
# 1    0.0703      **     0.8859     0.1099       10       8       19       119
# 2    0.0590      **     0.8588     0.0493        9      **        8        46
# 3    0.0681      **     0.8810     0.0895        8      **       27       116
# 4    0.0856  4.1881     0.8827     0.0544       **       5       21        98
#
#   Rte_hiv  Prop_uinC  Prop_uinA Prop_duinC  Prop_duinA Propt_HPI Rte_mein  \
# 0     208     0.0598     0.2070     0.0929      0.2291      43.3       **
# 1     330     0.0333     0.1745     0.0660      0.0924      75.5     33.8
# 2      56     0.0564     0.1245     0.1232      0.1876      73.4     22.0
# 3     196     0.0708     0.2404     0.1117      0.1918      34.2       **
# 4     171     0.0582     0.3259     0.0704      0.1874      22.3       **
#
#   Rte_cein Rte_luin  Prop_fru  Prop_bev  Prop_hyp  Prop_marj Prop_HI  \
# 0       **     34.6       0.2       0.2       0.2        0.1     0.0
# 1       **     35.3       0.1       0.3       0.3        0.2     0.1
# 2       **     29.5       0.1       0.2       0.2        0.0     0.0
# 3       **     29.7       0.1       0.4       0.2        0.1     0.0
# 4       **     26.5       0.1       0.4       0.3        0.1     0.0
#
#   Prop_grad  Prop_trua
# 0       1.0        0.1
# 1       0.9        0.4
# 2       1.0        0.1
# 3       0.9        0.0
# 4       1.0        0.4

# %%
# Capitalize "GEONAME" values
community_health_df["GEONAME"] = community_health_df["GEONAME"].str.upper()
community_health_df.head()
# Out:
#         GEONAME  Pop_Tot  Prop_18y  Prop_64y  Prop_65y+  Prop_Blk  Prop_Lat  \
# 0      ALHAMBRA    86705    0.1831    0.6504     0.1665    0.0133    0.3435
# 1      ALTADENA    42525    0.2072    0.6221     0.1707    0.2374    0.2905
# 2       ARCADIA    56992    0.1794    0.6389     0.1817    0.0115    0.1250
# 3         AZUSA    49479    0.2507    0.6538     0.0956    0.0292    0.6838
# 4  BALDWIN PARK    74438    0.2623    0.6330     0.1047    0.0099    0.7934
#
#    Prop_Whi  Prop_Asi  Prop_Ami  Prop_NHO  Prop_FPL1  Prop_FPL2  Prop_forb  \
# 0    0.0913    0.5498    0.0014    0.0007     0.1303     0.3356     0.5021
# 1    0.4129    0.0553    0.0019    0.0020     0.0988     0.2281     0.2021
# 2    0.2304    0.6315    0.0014    0.0003     0.0774     0.2042     0.4877
# 3    0.1938    0.0895    0.0024    0.0013     0.1636     0.3935     0.3082
# 4    0.0432    0.1514    0.0012    0.0008     0.1591     0.4116     0.4453
#
#   Prop_Eng     LE  Prop_prsc  Prop_3rdg  Prop_edLH  Prop_edHG  Prop_edSC  \
# 0   0.2112  84.55      0.665     0.5353     0.1934     0.2280     0.2497
# 1   0.0379  82.11      0.740     0.3942     0.1050     0.1397     0.2918
# 2   0.1888  85.42      0.675     0.7927     0.0789     0.1601     0.2430
# 3   0.1156  81.16      0.439     0.3390     0.2232     0.2932     0.2873
# 4   0.1908  82.99      0.470     0.3227     0.3740     0.3170     0.1962
#
#    Prop_edCG    MHI  No_libr  Prop_empl  Prop_emsu  Prop_vote  Rte_resp  \
# 0     0.3289  53582      1.0      0.940     0.3850     0.6235    0.7706
# 1     0.4635  86050      2.0      0.920     0.7335     0.7360    1.0975
# 2     0.5180  79934      1.0      0.941     0.5691     0.6271    1.9654
# 3     0.1962  53135      1.0      0.927     0.6201     0.6569    1.0168
# 4     0.1128  51742      1.0      0.898     0.5712     0.6318    0.3406
#
#    Prop_PA  Prop_groc  Prop_60mi No_farm No_EBT Prop_foin No_CalF Rte_CalF  \
# 0   0.2731     0.5239      0.111       1      1        **  15,799   0.3300
# 1   0.3482     0.4524      0.120       1      1        **       -        -
# 2   0.2662     0.5110      0.131       0      0        **   6,638   0.1800
# 3   0.3759     0.5997      0.121       0      0    0.2006   8,868   0.5800
# 4   0.3164     0.5444      0.125       1      1    0.2531  14,206   0.7400
#
#    Prop_FRPM Prop_obse Prop_DM Rte_coin  Rte_brin  Prop_smok Rte_luca  \
# 0     0.6598    0.1358  0.1040  45.7963  125.9019     0.1272  25.4872
# 1     0.5590    0.2441  0.1358  38.3670  189.2143     0.1129  25.2189
# 2     0.2066    0.0570  0.0819  32.9547  145.2497     0.1285  22.5416
# 3     0.8060    0.2607  0.1198  31.3309  134.9485     0.1174  34.8652
# 4     0.8729    0.2652  0.1307  43.8584  110.0378     0.1045  28.2446
#
#   Rte_COPD  Rte_CVD  Prop_hbu1  Prop_hbu2  Prop_ownr  Prop_rentr  No_hless  \
# 0  21.7535  170.914      0.447      0.232      0.404       0.596        64
# 1  28.4887  211.035      0.401      0.193      0.719       0.281        58
# 2  22.0580  173.371      0.402      0.214      0.596       0.404        12
# 3  33.1891  218.754      0.474      0.240      0.527       0.473        55
# 4  31.2708  195.522      0.498      0.227      0.572       0.428       111
#
#   Prop_asth  Rte_crim Rte_hom  Rte_alco Propt_envi No_gasw Rte_te17 Rte_te19  \
# 0    0.0449       168      **        12          6       2   2.1042   9.1180
# 1    0.0915       162      **         6         62       0   3.9610   7.6173
# 2        **       146      **        19         27       2       **       **
# 3    0.0660       354       6        14         48       0   3.5084   9.2802
# 4    0.0904       391       5        10          9       0   7.3997  20.1220
#
#    Prop_LBW Rte_IMR  Prop_1stt  Prop_depr Rte_suic Rte_UOD Rte_syin  Rte_goin  \
# 0    0.0815  3.1022     0.8614     0.0523        7       3       14        66
# 1    0.0703      **     0.8859     0.1099       10       8       19       119
# 2    0.0590      **     0.8588     0.0493        9      **        8        46
# 3    0.0681      **     0.8810     0.0895        8      **       27       116
# 4    0.0856  4.1881     0.8827     0.0544       **       5       21        98
#
#   Rte_hiv  Prop_uinC  Prop_uinA Prop_duinC  Prop_duinA Propt_HPI Rte_mein  \
# 0     208     0.0598     0.2070     0.0929      0.2291      43.3       **
# 1     330     0.0333     0.1745     0.0660      0.0924      75.5     33.8
# 2      56     0.0564     0.1245     0.1232      0.1876      73.4     22.0
# 3     196     0.0708     0.2404     0.1117      0.1918      34.2       **
# 4     171     0.0582     0.3259     0.0704      0.1874      22.3       **
#
#   Rte_cein Rte_luin  Prop_fru  Prop_bev  Prop_hyp  Prop_marj Prop_HI  \
# 0       **     34.6       0.2       0.2       0.2        0.1     0.0
# 1       **     35.3       0.1       0.3       0.3        0.2     0.1
# 2       **     29.5       0.1       0.2       0.2        0.0     0.0
# 3       **     29.7       0.1       0.4       0.2        0.1     0.0
# 4       **     26.5       0.1       0.4       0.3        0.1     0.0
#
#   Prop_grad  Prop_trua
# 0       1.0        0.1
# 1       0.9        0.4
# 2       1.0        0.1
# 3       0.9        0.0
# 4       1.0        0.4

# %%
# Drop columns as discussed
new_community_health_df = community_health_df.drop(columns = ["LE", 
                                                            "Prop_prsc", 
                                                            "Prop_3rdg", 
                                                            "No_libr", 
                                                            "Prop_empl", 
                                                            "Prop_emsu", 
                                                            "Prop_vote", 
                                                            "Rte_resp", 
                                                            "Prop_PA", 
                                                            "No_EBT", 
                                                            "No_CalF", 
                                                            "Rte_CalF", 
                                                            "Prop_FRPM", 
                                                            "Rte_coin", 
                                                            "Rte_brin", 
                                                            "Prop_smok", 
                                                            "Rte_luca", 
                                                            "Rte_COPD", 
                                                            "Prop_hbu1", 
                                                            "Prop_hbu2", 
                                                            "Prop_asth", 
                                                            "Rte_hom", 
                                                            "No_gasw", 
                                                            "Rte_te17", 
                                                            "Rte_te19", 
                                                            "Prop_LBW", 
                                                            "Rte_IMR", 
                                                            "Prop_1stt", 
                                                            "Rte_suic", 
                                                            "Rte_UOD", 
                                                            "Rte_syin", 
                                                            "Rte_goin", 
                                                            "Rte_hiv", 
                                                            "Prop_uinC", 
                                                            "Prop_uinA", 
                                                            "Prop_duinC", 
                                                            "Prop_duinA", 
                                                            "Rte_mein", 
                                                            "Rte_cein", 
                                                            "Rte_luin", 
                                                            "Prop_HI", 
                                                            "Prop_grad", 
                                                            "Prop_trua",
                                                            "Prop_foin"])

# Display DF
new_community_health_df.head()
# Out:
#         GEONAME  Pop_Tot  Prop_18y  Prop_64y  Prop_65y+  Prop_Blk  Prop_Lat  \
# 0      ALHAMBRA    86705    0.1831    0.6504     0.1665    0.0133    0.3435
# 1      ALTADENA    42525    0.2072    0.6221     0.1707    0.2374    0.2905
# 2       ARCADIA    56992    0.1794    0.6389     0.1817    0.0115    0.1250
# 3         AZUSA    49479    0.2507    0.6538     0.0956    0.0292    0.6838
# 4  BALDWIN PARK    74438    0.2623    0.6330     0.1047    0.0099    0.7934
#
#    Prop_Whi  Prop_Asi  Prop_Ami  Prop_NHO  Prop_FPL1  Prop_FPL2  Prop_forb  \
# 0    0.0913    0.5498    0.0014    0.0007     0.1303     0.3356     0.5021
# 1    0.4129    0.0553    0.0019    0.0020     0.0988     0.2281     0.2021
# 2    0.2304    0.6315    0.0014    0.0003     0.0774     0.2042     0.4877
# 3    0.1938    0.0895    0.0024    0.0013     0.1636     0.3935     0.3082
# 4    0.0432    0.1514    0.0012    0.0008     0.1591     0.4116     0.4453
#
#   Prop_Eng  Prop_edLH  Prop_edHG  Prop_edSC  Prop_edCG    MHI  Prop_groc  \
# 0   0.2112     0.1934     0.2280     0.2497     0.3289  53582     0.5239
# 1   0.0379     0.1050     0.1397     0.2918     0.4635  86050     0.4524
# 2   0.1888     0.0789     0.1601     0.2430     0.5180  79934     0.5110
# 3   0.1156     0.2232     0.2932     0.2873     0.1962  53135     0.5997
# 4   0.1908     0.3740     0.3170     0.1962     0.1128  51742     0.5444
#
#    Prop_60mi No_farm Prop_obse Prop_DM  Rte_CVD  Prop_ownr  Prop_rentr  \
# 0      0.111       1    0.1358  0.1040  170.914      0.404       0.596
# 1      0.120       1    0.2441  0.1358  211.035      0.719       0.281
# 2      0.131       0    0.0570  0.0819  173.371      0.596       0.404
# 3      0.121       0    0.2607  0.1198  218.754      0.527       0.473
# 4      0.125       1    0.2652  0.1307  195.522      0.572       0.428
#
#    No_hless  Rte_crim  Rte_alco Propt_envi  Prop_depr Propt_HPI  Prop_fru  \
# 0        64       168        12          6     0.0523      43.3       0.2
# 1        58       162         6         62     0.1099      75.5       0.1
# 2        12       146        19         27     0.0493      73.4       0.1
# 3        55       354        14         48     0.0895      34.2       0.1
# 4       111       391        10          9     0.0544      22.3       0.1
#
#    Prop_bev  Prop_hyp  Prop_marj
# 0       0.2       0.2        0.1
# 1       0.3       0.3        0.2
# 2       0.2       0.2        0.0
# 3       0.4       0.2        0.1
# 4       0.4       0.3        0.1

# %%
# Replace '**' with '0' as discussed
new_community_health_df.replace('**', 0)
# Out:
#                      GEONAME   Pop_Tot  Prop_18y  Prop_64y  Prop_65y+  \
# 0                   ALHAMBRA     86705    0.1831    0.6504     0.1665
# 1                   ALTADENA     42525    0.2072    0.6221     0.1707
# 2                    ARCADIA     56992    0.1794    0.6389     0.1817
# 3                      AZUSA     49479    0.2507    0.6538     0.0956
# 4               BALDWIN PARK     74438    0.2623    0.6330     0.1047
# ..                       ...       ...       ...       ...        ...
# 82            WEST HOLLYWOOD     35797    0.0639    0.7801     0.1560
# 83  WEST WHITTIER-LOS NIETOS     25441    0.2426    0.6253     0.1321
# 84                  WESTMONT     32835    0.2823    0.6208     0.0968
# 85                  WHITTIER     88078    0.2304    0.6385     0.1311
# 86        LOS ANGELES COUNTY  10227450    0.2253    0.6471     0.1276
#
#     Prop_Blk  Prop_Lat  Prop_Whi  Prop_Asi  Prop_Ami  Prop_NHO  Prop_FPL1  \
# 0     0.0133    0.3435    0.0913    0.5498    0.0014    0.0007     0.1303
# 1     0.2374    0.2905    0.4129    0.0553    0.0019    0.0020     0.0988
# 2     0.0115    0.1250    0.2304    0.6315    0.0014    0.0003     0.0774
# 3     0.0292    0.6838    0.1938    0.0895    0.0024    0.0013     0.1636
# 4     0.0099    0.7934    0.0432    0.1514    0.0012    0.0008     0.1591
# ..       ...       ...       ...       ...       ...       ...        ...
# 82    0.0310    0.1081    0.7984    0.0603    0.0014    0.0008     0.1403
# 83    0.0080    0.8775    0.0954    0.0147    0.0032    0.0013     0.0912
# 84    0.4945    0.4912    0.0096    0.0025    0.0012    0.0009     0.3546
# 85    0.0098    0.6750    0.2752    0.0361    0.0028    0.0011     0.1081
# 86    0.0846    0.4876    0.2804    0.1431    0.0019    0.0024     0.1673
#
#     Prop_FPL2  Prop_forb Prop_Eng  Prop_edLH  Prop_edHG  Prop_edSC  Prop_edCG  \
# 0      0.3356     0.5021   0.2112     0.1934     0.2280     0.2497     0.3289
# 1      0.2281     0.2021   0.0379     0.1050     0.1397     0.2918     0.4635
# 2      0.2042     0.4877   0.1888     0.0789     0.1601     0.2430     0.5180
# 3      0.3935     0.3082   0.1156     0.2232     0.2932     0.2873     0.1962
# 4      0.4116     0.4453   0.1908     0.3740     0.3170     0.1962     0.1128
# ..        ...        ...      ...        ...        ...        ...        ...
# 82     0.2798     0.2587   0.1023     0.0456     0.0884     0.2404     0.6257
# 83     0.2858     0.2691   0.0987     0.2858     0.3170     0.2711     0.1262
# 84     0.6729     0.2324   0.1142     0.3041     0.2962     0.3272     0.0725
# 85     0.3274     0.1770   0.0542     0.1672     0.2376     0.3531     0.2421
# 86     0.3766     0.3472   0.1374     0.2272     0.2068     0.2633     0.3027
#
#       MHI  Prop_groc  Prop_60mi No_farm Prop_obse Prop_DM   Rte_CVD  \
# 0   53582     0.5239      0.111       1    0.1358  0.1040  170.9140
# 1   86050     0.4524      0.120       1    0.2441  0.1358  211.0350
# 2   79934     0.5110      0.131       0    0.0570  0.0819  173.3710
# 3   53135     0.5997      0.121       0    0.2607  0.1198  218.7540
# 4   51742     0.5444      0.125       1    0.2652  0.1307  195.5220
# ..    ...        ...        ...     ...       ...     ...       ...
# 82  56317     0.9850      0.062       1    0.2207  0.0804  176.8870
# 83  65363     0.4991      0.107       0    0.3584  0.1234  217.1750
# 84  26808     0.1988      0.184       0    0.3195  0.1852  308.4830
# 85  66457     0.3930      0.125       1    0.2773  0.1291  199.0170
# 86  56196     0.6185      0.125       -    0.2352  0.0983  204.8349
#
#     Prop_ownr  Prop_rentr  No_hless  Rte_crim  Rte_alco Propt_envi  Prop_depr  \
# 0       0.404      0.5960        64       168        12          6     0.0523
# 1       0.719      0.2810        58       162         6         62     0.1099
# 2       0.596      0.4040        12       146        19         27     0.0493
# 3       0.527      0.4730        55       354        14         48     0.0895
# 4       0.572      0.4280       111       391        10          9     0.0544
# ..        ...         ...       ...       ...       ...        ...        ...
# 82      0.201      0.7990        81       768        61         29     0.1503
# 83      0.721      0.2790        36       307         9         26     0.0791
# 84      0.306      0.6940       365      1514         7         69     0.0703
# 85      0.569      0.4310       258       293        16         63     0.0756
# 86      0.460      0.5403     46874       551        15          -     0.0861
#
#    Propt_HPI  Prop_fru  Prop_bev  Prop_hyp  Prop_marj
# 0       43.3       0.2       0.2       0.2        0.1
# 1       75.5       0.1       0.3       0.3        0.2
# 2       73.4       0.1       0.2       0.2        0.0
# 3       34.2       0.1       0.4       0.2        0.1
# 4       22.3       0.1       0.4       0.3        0.1
# ..       ...       ...       ...       ...        ...
# 82      70.6       0.4       0.2       0.2        0.2
# 83      41.2       0.1       0.4       0.2        0.1
# 84       0.6       0.2       0.4       0.3        0.0
# 85      53.8       0.2       0.3       0.3        0.1
# 86         -       0.1       0.4       0.2        0.1
#
# [87 rows x 38 columns]

# %%
# Replace '-' with '0' as discussed
new_community_health_df.replace('-', 0)
# Out:
#                      GEONAME   Pop_Tot  Prop_18y  Prop_64y  Prop_65y+  \
# 0                   ALHAMBRA     86705    0.1831    0.6504     0.1665
# 1                   ALTADENA     42525    0.2072    0.6221     0.1707
# 2                    ARCADIA     56992    0.1794    0.6389     0.1817
# 3                      AZUSA     49479    0.2507    0.6538     0.0956
# 4               BALDWIN PARK     74438    0.2623    0.6330     0.1047
# ..                       ...       ...       ...       ...        ...
# 82            WEST HOLLYWOOD     35797    0.0639    0.7801     0.1560
# 83  WEST WHITTIER-LOS NIETOS     25441    0.2426    0.6253     0.1321
# 84                  WESTMONT     32835    0.2823    0.6208     0.0968
# 85                  WHITTIER     88078    0.2304    0.6385     0.1311
# 86        LOS ANGELES COUNTY  10227450    0.2253    0.6471     0.1276
#
#     Prop_Blk  Prop_Lat  Prop_Whi  Prop_Asi  Prop_Ami  Prop_NHO  Prop_FPL1  \
# 0     0.0133    0.3435    0.0913    0.5498    0.0014    0.0007     0.1303
# 1     0.2374    0.2905    0.4129    0.0553    0.0019    0.0020     0.0988
# 2     0.0115    0.1250    0.2304    0.6315    0.0014    0.0003     0.0774
# 3     0.0292    0.6838    0.1938    0.0895    0.0024    0.0013     0.1636
# 4     0.0099    0.7934    0.0432    0.1514    0.0012    0.0008     0.1591
# ..       ...       ...       ...       ...       ...       ...        ...
# 82    0.0310    0.1081    0.7984    0.0603    0.0014    0.0008     0.1403
# 83    0.0080    0.8775    0.0954    0.0147    0.0032    0.0013     0.0912
# 84    0.4945    0.4912    0.0096    0.0025    0.0012    0.0009     0.3546
# 85    0.0098    0.6750    0.2752    0.0361    0.0028    0.0011     0.1081
# 86    0.0846    0.4876    0.2804    0.1431    0.0019    0.0024     0.1673
#
#     Prop_FPL2  Prop_forb Prop_Eng  Prop_edLH  Prop_edHG  Prop_edSC  Prop_edCG  \
# 0      0.3356     0.5021   0.2112     0.1934     0.2280     0.2497     0.3289
# 1      0.2281     0.2021   0.0379     0.1050     0.1397     0.2918     0.4635
# 2      0.2042     0.4877   0.1888     0.0789     0.1601     0.2430     0.5180
# 3      0.3935     0.3082   0.1156     0.2232     0.2932     0.2873     0.1962
# 4      0.4116     0.4453   0.1908     0.3740     0.3170     0.1962     0.1128
# ..        ...        ...      ...        ...        ...        ...        ...
# 82     0.2798     0.2587   0.1023     0.0456     0.0884     0.2404     0.6257
# 83     0.2858     0.2691   0.0987     0.2858     0.3170     0.2711     0.1262
# 84     0.6729     0.2324   0.1142     0.3041     0.2962     0.3272     0.0725
# 85     0.3274     0.1770   0.0542     0.1672     0.2376     0.3531     0.2421
# 86     0.3766     0.3472   0.1374     0.2272     0.2068     0.2633     0.3027
#
#       MHI  Prop_groc  Prop_60mi No_farm Prop_obse Prop_DM   Rte_CVD  \
# 0   53582     0.5239      0.111       1    0.1358  0.1040  170.9140
# 1   86050     0.4524      0.120       1    0.2441  0.1358  211.0350
# 2   79934     0.5110      0.131       0    0.0570  0.0819  173.3710
# 3   53135     0.5997      0.121       0    0.2607  0.1198  218.7540
# 4   51742     0.5444      0.125       1    0.2652  0.1307  195.5220
# ..    ...        ...        ...     ...       ...     ...       ...
# 82  56317     0.9850      0.062       1    0.2207  0.0804  176.8870
# 83  65363     0.4991      0.107       0    0.3584  0.1234  217.1750
# 84  26808     0.1988      0.184       0    0.3195  0.1852  308.4830
# 85  66457     0.3930      0.125       1    0.2773  0.1291  199.0170
# 86  56196     0.6185      0.125       0    0.2352  0.0983  204.8349
#
#     Prop_ownr  Prop_rentr  No_hless  Rte_crim  Rte_alco Propt_envi  Prop_depr  \
# 0       0.404      0.5960        64       168        12          6     0.0523
# 1       0.719      0.2810        58       162         6         62     0.1099
# 2       0.596      0.4040        12       146        19         27     0.0493
# 3       0.527      0.4730        55       354        14         48     0.0895
# 4       0.572      0.4280       111       391        10          9     0.0544
# ..        ...         ...       ...       ...       ...        ...        ...
# 82      0.201      0.7990        81       768        61         29     0.1503
# 83      0.721      0.2790        36       307         9         26     0.0791
# 84      0.306      0.6940       365      1514         7         69     0.0703
# 85      0.569      0.4310       258       293        16         63     0.0756
# 86      0.460      0.5403     46874       551        15          0     0.0861
#
#    Propt_HPI  Prop_fru  Prop_bev  Prop_hyp  Prop_marj
# 0       43.3       0.2       0.2       0.2        0.1
# 1       75.5       0.1       0.3       0.3        0.2
# 2       73.4       0.1       0.2       0.2        0.0
# 3       34.2       0.1       0.4       0.2        0.1
# 4       22.3       0.1       0.4       0.3        0.1
# ..       ...       ...       ...       ...        ...
# 82      70.6       0.4       0.2       0.2        0.2
# 83      41.2       0.1       0.4       0.2        0.1
# 84       0.6       0.2       0.4       0.3        0.0
# 85      53.8       0.2       0.3       0.3        0.1
# 86         0       0.1       0.4       0.2        0.1
#
# [87 rows x 38 columns]

# %%
# Check data types
for column in new_community_health_df.columns:
    print(f"Column {column} has data type -- {community_health_df[column].dtype}.")
# Out:
# Column GEONAME has data type -- object.
# Column Pop_Tot has data type -- int64.
# Column Prop_18y has data type -- float64.
# Column Prop_64y has data type -- float64.
# Column Prop_65y+ has data type -- float64.
# Column Prop_Blk has data type -- float64.
# Column Prop_Lat has data type -- float64.
# Column Prop_Whi has data type -- float64.
# Column Prop_Asi has data type -- float64.
# Column Prop_Ami has data type -- float64.
# Column Prop_NHO has data type -- float64.
# Column Prop_FPL1 has data type -- float64.
# Column Prop_FPL2 has data type -- float64.
# Column Prop_forb has data type -- float64.
# Column Prop_Eng has data type -- object.
# Column Prop_edLH has data type -- float64.
# Column Prop_edHG has data type -- float64.
# Column Prop_edSC has data type -- float64.
# Column Prop_edCG has data type -- float64.
# Column MHI has data type -- int64.
# Column Prop_groc has data type -- float64.
# Column Prop_60mi has data type -- float64.
# Column No_farm has data type -- object.
# Column Prop_obse has data type -- object.
# Column Prop_DM has data type -- object.
# Column Rte_CVD has data type -- float64.
# Column Prop_ownr has data type -- float64.
# Column Prop_rentr has data type -- float64.
# Column No_hless has data type -- int64.
# Column Rte_crim has data type -- int64.
# Column Rte_alco has data type -- int64.
# Column Propt_envi has data type -- object.
# Column Prop_depr has data type -- float64.
# Column Propt_HPI has data type -- object.
# Column Prop_fru has data type -- float64.
# Column Prop_bev has data type -- float64.
# Column Prop_hyp has data type -- float64.
# Column Prop_marj has data type -- float64.

# %%
# Change select columns to string
new_community_health_df[["GEONAME", 
                         "Prop_Eng", 
                         "No_farm", 
                         "Prop_obse", 
                         "Propt_envi", 
                         "Propt_HPI"]] = new_community_health_df[["GEONAME", 
                                                                  "Prop_Eng", 
                                                                  "No_farm", 
                                                                  "Prop_obse", 
                                                                  "Propt_envi", 
                                                                  "Propt_HPI"]].astype(str)

# %%
# Check for null values
for column in new_community_health_df.columns:
    print(f"Column {column} has {new_community_health_df[column].isnull().sum()} null values.")
# Out:
# Column GEONAME has 0 null values.
# Column Pop_Tot has 0 null values.
# Column Prop_18y has 0 null values.
# Column Prop_64y has 0 null values.
# Column Prop_65y+ has 0 null values.
# Column Prop_Blk has 0 null values.
# Column Prop_Lat has 0 null values.
# Column Prop_Whi has 0 null values.
# Column Prop_Asi has 0 null values.
# Column Prop_Ami has 0 null values.
# Column Prop_NHO has 0 null values.
# Column Prop_FPL1 has 0 null values.
# Column Prop_FPL2 has 0 null values.
# Column Prop_forb has 0 null values.
# Column Prop_Eng has 0 null values.
# Column Prop_edLH has 0 null values.
# Column Prop_edHG has 0 null values.
# Column Prop_edSC has 0 null values.
# Column Prop_edCG has 0 null values.
# Column MHI has 0 null values.
# Column Prop_groc has 0 null values.
# Column Prop_60mi has 0 null values.
# Column No_farm has 0 null values.
# Column Prop_obse has 0 null values.
# Column Prop_DM has 0 null values.
# Column Rte_CVD has 0 null values.
# Column Prop_ownr has 0 null values.
# Column Prop_rentr has 0 null values.
# Column No_hless has 0 null values.
# Column Rte_crim has 0 null values.
# Column Rte_alco has 0 null values.
# Column Propt_envi has 0 null values.
# Column Prop_depr has 0 null values.
# Column Propt_HPI has 0 null values.
# Column Prop_fru has 0 null values.
# Column Prop_bev has 0 null values.
# Column Prop_hyp has 0 null values.
# Column Prop_marj has 0 null values.

# %%
# Check shape
new_community_health_df.shape
# Out:
# (87, 38)

# %%
# Export to csv
new_community_health_df.to_csv("./Resources/Clean/clean_community_health.csv")

# %% [markdown]
# **NEXT STEP**: Review and update 'GEONAME' in SQL.
