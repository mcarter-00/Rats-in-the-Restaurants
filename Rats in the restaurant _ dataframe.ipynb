# %%
import pandas as pd

# %%
file_path = "Resources/LOS_ANGELES_COUNTY_RESTAURANT_AND_MARKET_INSPECTIONS.csv"
restaurant_list_df = pd.read_csv(file_path,index_col=0)
restaurant_list_df
# Out:
#                 OWNER ID                   OWNER NAME FACILITY ID  \
# ACTIVITY DATE
# 09/10/2018     OW0105348  GUCKENHEIMER SERVICES, LLC.   FA0242046
# 07/19/2018     OW0246461           ANASTACIOS POLITIS   FA0252769
# 08/15/2018     OW0010130   DJ BIBINGKAHAN CORPORATION   FA0011237
# 07/16/2018     OW0020051               KULWINDER KAUR   FA0061073
# 09/07/2018     OW0246329                JUAN C OROZCO   FA0252595
# ...                  ...                          ...         ...
# 03/04/2020     OW0104646             MORSY FARMS CORP   FA0141514
# 03/05/2020     OW0257864                 BY SONG INC.   FA0267258
# 03/12/2020     OW0030803    ROSS DRESS FOR LESS, INC.   FA0069781
# 03/03/2020     OW0255835            LA FIESTA # 1 LLC   FA0264750
# 03/10/2020     OW0184101             JUAN PEDRO AMAYA   FA0178332
#
#                                   FACILITY NAME  RECORD ID  \
# ACTIVITY DATE
# 09/10/2018                 SERVERY- NICKELODEON  PR0190194
# 07/19/2018                      TOMS JR BURGERS  PR0202127
# 08/15/2018                       DJ BIBINGKAHAN  PR0035416
# 07/16/2018                        DOROSE LIQUOR  PR0027907
# 09/07/2018     MEJICO GRILL AND TEQUILLA LOUNGE  PR0201914
# ...                                         ...        ...
# 03/04/2020                          MORSY FARMS  PR0128205
# 03/05/2020                     SWEETY'S CANDIES  PR0218659
# 03/12/2020                 ROSS STORES INC #323  PR0002415
# 03/03/2020                        LA FIESTA # 1  PR0215888
# 03/10/2020                  SUPER TOM'S BURGERS  PR0171459
#
#                                    PROGRAM NAME PROGRAM STATUS  \
# ACTIVITY DATE
# 09/10/2018                 SERVERY- NICKELODEON         ACTIVE
# 07/19/2018                      TOMS JR BURGERS         ACTIVE
# 08/15/2018              DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 07/16/2018                        DOROSE LIQUOR         ACTIVE
# 09/07/2018     MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# ...                                         ...            ...
# 03/04/2020                          MORSY FARMS         ACTIVE
# 03/05/2020                     SWEETY'S CANDIES         ACTIVE
# 03/12/2020                     ROSS STORES #323         ACTIVE
# 03/03/2020                        LA FIESTA # 1         ACTIVE
# 03/10/2020                  SUPER TOM'S BURGERS         ACTIVE
#
#                PROGRAM ELEMENT (PE)  \
# ACTIVITY DATE
# 09/10/2018                     1635
# 07/19/2018                     1632
# 08/15/2018                     1631
# 07/16/2018                     1610
# 09/07/2018                     1641
# ...                             ...
# 03/04/2020                     1611
# 03/05/2020                     1610
# 03/12/2020                     1610
# 03/03/2020                     1635
# 03/10/2020                     1638
#
#                                            PE DESCRIPTION  \
# ACTIVITY DATE
# 09/10/2018             RESTAURANT (31-60) SEATS HIGH RISK
# 07/19/2018              RESTAURANT (0-30) SEATS HIGH RISK
# 08/15/2018          RESTAURANT (0-30) SEATS MODERATE RISK
# 07/16/2018          FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 09/07/2018            RESTAURANT (151 + ) SEATS HIGH RISK
# ...                                                   ...
# 03/04/2020     FOOD MKT RETAIL (1-1,999 SF) MODERATE RISK
# 03/05/2020          FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 03/12/2020          FOOD MKT RETAIL (1-1,999 SF) LOW RISK
# 03/03/2020             RESTAURANT (31-60) SEATS HIGH RISK
# 03/10/2020            RESTAURANT (61-150) SEATS HIGH RISK
#
#                                         FACILITY ADDRESS  FACILITY CITY  \
# ACTIVITY DATE
# 09/10/2018                           203 W OLIVE AVE # C        BURBANK
# 07/19/2018     1030 W MARTIN LUTHER KING JR BLVD STE 108    LOS ANGELES
# 08/15/2018                                1515 E AMAR RD    WEST COVINA
# 07/16/2018                             13560 ROSCOE BLVD  PANORAMA CITY
# 09/07/2018                               29002 AGOURA RD   AGOURA HILLS
# ...                                                  ...            ...
# 03/04/2020                            6900 S CENTRAL AVE    LOS ANGELES
# 03/05/2020                          164 E PALM AVE # 104        BURBANK
# 03/12/2020                         3033 S SEPULVEDA BLVD    LOS ANGELES
# 03/03/2020                             18515 ROSCOE BLVD     NORTHRIDGE
# 03/10/2020                           444 E FOOTHILL BLVD          AZUSA
#
#               FACILITY STATE FACILITY ZIP  SERVICE CODE SERVICE DESCRIPTION  \
# ACTIVITY DATE
# 09/10/2018                CA        91502             1  ROUTINE INSPECTION
# 07/19/2018                CA   90037-1867             1  ROUTINE INSPECTION
# 08/15/2018                CA        91792             1  ROUTINE INSPECTION
# 07/16/2018                CA        91402             1  ROUTINE INSPECTION
# 09/07/2018                CA        91301             1  ROUTINE INSPECTION
# ...                      ...          ...           ...                 ...
# 03/04/2020                CA   90001-1646             1  ROUTINE INSPECTION
# 03/05/2020                CA        91502             1  ROUTINE INSPECTION
# 03/12/2020                CA        90034             1  ROUTINE INSPECTION
# 03/03/2020                CA        91324             1  ROUTINE INSPECTION
# 03/10/2020                CA        91702             1  ROUTINE INSPECTION
#
#                SCORE GRADE SERIAL NUMBER EMPLOYEE ID  \
# ACTIVITY DATE
# 09/10/2018        96     A     DARRFUZBW   EE0000495
# 07/19/2018        98     A     DA0XQVMTN   EE0001130
# 08/15/2018        98     A     DAMPOJNY8   EE0000500
# 07/16/2018        91     A     DAUTU3DPD   EE0000045
# 09/07/2018        90     A     DAUEU4NGF   EE0000526
# ...              ...   ...           ...         ...
# 03/04/2020        94     A     DAGR0JJEN   EE0000141
# 03/05/2020       100     A     DADGIFICA   EE0000451
# 03/12/2020        97     A     DALVVBO2J   EE0001013
# 03/03/2020        96     A     DAH0HFNIW   EE0000688
# 03/10/2020        94     A     DALQRTJE3   EE0000431
#
#                                     Location
# ACTIVITY DATE
# 09/10/2018     POINT (-118.314661 34.175253)
# 07/19/2018     POINT (-118.292543 34.010859)
# 08/15/2018     POINT (-117.913926 34.030964)
# 07/16/2018     POINT (-118.428399 34.221664)
# 09/07/2018     POINT (-118.756808 34.143452)
# ...                                      ...
# 03/04/2020     POINT (-118.256415 33.977551)
# 03/05/2020     POINT (-118.310988 34.182068)
# 03/12/2020     POINT (-118.427883 34.026393)
# 03/03/2020      POINT (-118.53732 34.220723)
# 03/10/2020     POINT (-117.902822 34.133457)
#
# [210427 rows x 20 columns]

# %%
# loop through each column, check if there are null values, 
#sum them up, and print out a readable total:
for column in restaurant_list_df.columns:
    print(f"Column {column} has {restaurant_list_df[column].isnull().sum()} null values")
# Out:
# Column OWNER ID has 0 null values
# Column OWNER NAME has 0 null values
# Column FACILITY ID has 0 null values
# Column FACILITY NAME has 0 null values
# Column RECORD ID has 0 null values
# Column PROGRAM NAME has 0 null values
# Column PROGRAM STATUS has 0 null values
# Column PROGRAM ELEMENT (PE) has 0 null values
# Column PE DESCRIPTION has 0 null values
# Column FACILITY ADDRESS has 0 null values
# Column FACILITY CITY has 0 null values
# Column FACILITY STATE has 0 null values
# Column FACILITY ZIP has 0 null values
# Column SERVICE CODE has 0 null values
# Column SERVICE DESCRIPTION has 0 null values
# Column SCORE has 0 null values
# Column GRADE has 77 null values
# Column SERIAL NUMBER has 0 null values
# Column EMPLOYEE ID has 0 null values
# Column Location has 7106 null values

# %%
#check PE DESCRIPTION options
restaurant_list_df.groupby("PE DESCRIPTION").count().index
# Out:
# Index(['CATERER (0-999 SQ. FT.)', 'CATERER (1,000-1,999 SQ. FT.)',
#        'FOOD MARKET WHOLESALE', 'FOOD MKT RETAIL (1-1,999 SF) HIGH RISK',
#        'FOOD MKT RETAIL (1-1,999 SF) LOW RISK',
#        'FOOD MKT RETAIL (1-1,999 SF) MODERATE RISK',
#        'FOOD MKT RETAIL (2,000+ SF) HIGH RISK',
#        'FOOD MKT RETAIL (2,000+ SF) LOW RISK',
#        'FOOD MKT RETAIL (2,000+ SF) MODERATE RISK',
#        'FOOD PROCESSING WHOLESALE (1-1,999 SQ. FT.)',
#        'FOOD PROCESSING WHOLESALE (2,000-5,999 SF)',
#        'FOOD PROCESSING WHOLESALE (6,000 + SQ. FT.)',
#        'FOOD VEHICLE COMMISSARY (0-10)', 'FOOD WAREHOUSE (1-4,999) SQ. FT.',
#        'INTERIM HOUSING FF (1-1,999) SQ. FT.',
#        'INTERIM HOUSING FF (2,000-4,999) SQ. FT.',
#        'LIC HTH CARE FOOD FAC (0-1999 SF) HIGH RISK',
#        'LIC HTH CARE FOOD FAC (0-1999 SF) MOD RISK',
#        'LIC HTH CARE FOOD FAC (10,000+ SF) HIGH RISK',
#        'LIC HTH CARE FOOD FAC (2000-3999 SF)HIGH RISK',
#        'LIC HTH CARE FOOD FAC (4000-9999 SF)HIGH RISK',
#        'PRIVATE SCHOOL CAFETERIA', 'RESTAURANT (0-30) SEATS HIGH RISK',
#        'RESTAURANT (0-30) SEATS LOW RISK',
#        'RESTAURANT (0-30) SEATS MODERATE RISK',
#        'RESTAURANT (151 + ) SEATS HIGH RISK',
#        'RESTAURANT (151 + ) SEATS LOW RISK',
#        'RESTAURANT (151 + ) SEATS MODERATE RISK',
#        'RESTAURANT (31-60) SEATS HIGH RISK',
#        'RESTAURANT (31-60) SEATS LOW RISK',
#        'RESTAURANT (31-60) SEATS MODERATE RISK',
#        'RESTAURANT (61-150) SEATS HIGH RISK',
#        'RESTAURANT (61-150) SEATS LOW RISK',
#        'RESTAURANT (61-150) SEATS MODERATE RISK'],
#       dtype='object', name='PE DESCRIPTION')

# %%
#Remove all PE DESCRIPTION that are not restaurants
restaurant_list2_df= restaurant_list_df.loc[restaurant_list_df['PE DESCRIPTION'].str.contains('RESTAURANT')]
restaurant_list2_df
# Out:
#                 OWNER ID                   OWNER NAME FACILITY ID  \
# ACTIVITY DATE
# 09/10/2018     OW0105348  GUCKENHEIMER SERVICES, LLC.   FA0242046
# 07/19/2018     OW0246461           ANASTACIOS POLITIS   FA0252769
# 08/15/2018     OW0010130   DJ BIBINGKAHAN CORPORATION   FA0011237
# 09/07/2018     OW0246329                JUAN C OROZCO   FA0252595
# 09/18/2018     OW0123199      REDONDO ENTERPRISES LLC   FA0158101
# ...                  ...                          ...         ...
# 02/27/2020     OW0267763     CALIF CHICKEN NINE , INC   FA0278951
# 03/10/2020     OW0027458           PANDA EXPRESS INC.   FA0043076
# 03/31/2020     OW0016998       IN-N-OUT BURGERS, INC.   FA0030146
# 03/03/2020     OW0255835            LA FIESTA # 1 LLC   FA0264750
# 03/10/2020     OW0184101             JUAN PEDRO AMAYA   FA0178332
#
#                                   FACILITY NAME  RECORD ID  \
# ACTIVITY DATE
# 09/10/2018                 SERVERY- NICKELODEON  PR0190194
# 07/19/2018                      TOMS JR BURGERS  PR0202127
# 08/15/2018                       DJ BIBINGKAHAN  PR0035416
# 09/07/2018     MEJICO GRILL AND TEQUILLA LOUNGE  PR0201914
# 09/18/2018                    MCDONALD'S #10681  PR0146191
# ...                                         ...        ...
# 02/27/2020              CALIFORNIA CHICKEN CAFE  PR0233062
# 03/10/2020                  PANDA EXPRESS #2018  PR0020389
# 03/31/2020                  IN-N-OUT BURGER #27  PR0020544
# 03/03/2020                        LA FIESTA # 1  PR0215888
# 03/10/2020                  SUPER TOM'S BURGERS  PR0171459
#
#                                    PROGRAM NAME PROGRAM STATUS  \
# ACTIVITY DATE
# 09/10/2018                 SERVERY- NICKELODEON         ACTIVE
# 07/19/2018                      TOMS JR BURGERS         ACTIVE
# 08/15/2018              DJ BIBINGKAHAN BAKESHOP         ACTIVE
# 09/07/2018     MEJICO GRILL AND TEQUILLA LOUNGE         ACTIVE
# 09/18/2018                    MCDONALD'S #10681         ACTIVE
# ...                                         ...            ...
# 02/27/2020              CALIFORNIA CHICKEN CAFE         ACTIVE
# 03/10/2020                  PANDA EXPRESS #2018         ACTIVE
# 03/31/2020                  IN-N-OUT BURGER #27         ACTIVE
# 03/03/2020                        LA FIESTA # 1         ACTIVE
# 03/10/2020                  SUPER TOM'S BURGERS         ACTIVE
#
#                PROGRAM ELEMENT (PE)                           PE DESCRIPTION  \
# ACTIVITY DATE
# 09/10/2018                     1635       RESTAURANT (31-60) SEATS HIGH RISK
# 07/19/2018                     1632        RESTAURANT (0-30) SEATS HIGH RISK
# 08/15/2018                     1631    RESTAURANT (0-30) SEATS MODERATE RISK
# 09/07/2018                     1641      RESTAURANT (151 + ) SEATS HIGH RISK
# 09/18/2018                     1637  RESTAURANT (61-150) SEATS MODERATE RISK
# ...                             ...                                      ...
# 02/27/2020                     1635       RESTAURANT (31-60) SEATS HIGH RISK
# 03/10/2020                     1635       RESTAURANT (31-60) SEATS HIGH RISK
# 03/31/2020                     1631    RESTAURANT (0-30) SEATS MODERATE RISK
# 03/03/2020                     1635       RESTAURANT (31-60) SEATS HIGH RISK
# 03/10/2020                     1638      RESTAURANT (61-150) SEATS HIGH RISK
#
#                                         FACILITY ADDRESS FACILITY CITY  \
# ACTIVITY DATE
# 09/10/2018                           203 W OLIVE AVE # C       BURBANK
# 07/19/2018     1030 W MARTIN LUTHER KING JR BLVD STE 108   LOS ANGELES
# 08/15/2018                                1515 E AMAR RD   WEST COVINA
# 09/07/2018                               29002 AGOURA RD  AGOURA HILLS
# 09/18/2018                             5725 FLORENCE AVE  BELL GARDENS
# ...                                                  ...           ...
# 02/27/2020                                 809 S HILL ST   LOS ANGELES
# 03/10/2020                      15528 WHITTIER BLVD # #B      WHITTIER
# 03/31/2020                         420 N SANTA ANITA AVE       ARCADIA
# 03/03/2020                             18515 ROSCOE BLVD    NORTHRIDGE
# 03/10/2020                           444 E FOOTHILL BLVD         AZUSA
#
#               FACILITY STATE FACILITY ZIP  SERVICE CODE SERVICE DESCRIPTION  \
# ACTIVITY DATE
# 09/10/2018                CA        91502             1  ROUTINE INSPECTION
# 07/19/2018                CA   90037-1867             1  ROUTINE INSPECTION
# 08/15/2018                CA        91792             1  ROUTINE INSPECTION
# 09/07/2018                CA        91301             1  ROUTINE INSPECTION
# 09/18/2018                CA        90201             1  ROUTINE INSPECTION
# ...                      ...          ...           ...                 ...
# 02/27/2020                CA   90014-3103             1  ROUTINE INSPECTION
# 03/10/2020                CA        90603             1  ROUTINE INSPECTION
# 03/31/2020                CA        91006             1  ROUTINE INSPECTION
# 03/03/2020                CA        91324             1  ROUTINE INSPECTION
# 03/10/2020                CA        91702             1  ROUTINE INSPECTION
#
#                SCORE GRADE SERIAL NUMBER EMPLOYEE ID  \
# ACTIVITY DATE
# 09/10/2018        96     A     DARRFUZBW   EE0000495
# 07/19/2018        98     A     DA0XQVMTN   EE0001130
# 08/15/2018        98     A     DAMPOJNY8   EE0000500
# 09/07/2018        90     A     DAUEU4NGF   EE0000526
# 09/18/2018        91     A     DARQIUA45   EE0000437
# ...              ...   ...           ...         ...
# 02/27/2020        96     A     DA96YTYI2   EE0001064
# 03/10/2020        95     A     DAUHBHK0C   EE0000926
# 03/31/2020       100     A     DAPOZY6B7   EE0000232
# 03/03/2020        96     A     DAH0HFNIW   EE0000688
# 03/10/2020        94     A     DALQRTJE3   EE0000431
#
#                                     Location
# ACTIVITY DATE
# 09/10/2018     POINT (-118.314661 34.175253)
# 07/19/2018     POINT (-118.292543 34.010859)
# 08/15/2018     POINT (-117.913926 34.030964)
# 09/07/2018     POINT (-118.756808 34.143452)
# 09/18/2018     POINT (-118.163665 33.967791)
# ...                                      ...
# 02/27/2020     POINT (-118.255985 34.044257)
# 03/10/2020     POINT (-117.995246 33.945004)
# 03/31/2020     POINT (-118.031451 34.145206)
# 03/03/2020      POINT (-118.53732 34.220723)
# 03/10/2020     POINT (-117.902822 34.133457)
#
# [171862 rows x 20 columns]

# %%
#check PE DESCRIPTION options
restaurant_list2_df.groupby("PE DESCRIPTION").count().index
# Out:
# Index(['RESTAURANT (0-30) SEATS HIGH RISK', 'RESTAURANT (0-30) SEATS LOW RISK',
#        'RESTAURANT (0-30) SEATS MODERATE RISK',
#        'RESTAURANT (151 + ) SEATS HIGH RISK',
#        'RESTAURANT (151 + ) SEATS LOW RISK',
#        'RESTAURANT (151 + ) SEATS MODERATE RISK',
#        'RESTAURANT (31-60) SEATS HIGH RISK',
#        'RESTAURANT (31-60) SEATS LOW RISK',
#        'RESTAURANT (31-60) SEATS MODERATE RISK',
#        'RESTAURANT (61-150) SEATS HIGH RISK',
#        'RESTAURANT (61-150) SEATS LOW RISK',
#        'RESTAURANT (61-150) SEATS MODERATE RISK'],
#       dtype='object', name='PE DESCRIPTION')
