# %%
# Initial imports.
import pandas as pd
import numpy as np


from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

pd.set_option('display.max_columns', 999)

# %%
file_path = "Resources/clean_new_rats_JUNE09.csv"
restaurant_list_df = pd.read_csv(file_path)
restaurant_list_df
# Out:
#         Unnamed: 0 ACTIVITY_DATE FACILITY_ID        FACILITY_NAME  \
# 0                0    2020-02-04   FA0240932  THE GREAT ROOM CAFE
# 1                1    2020-02-04   FA0240932  THE GREAT ROOM CAFE
# 2                2    2020-02-04   FA0240932  THE GREAT ROOM CAFE
# 3                3    2020-02-04   FA0240932  THE GREAT ROOM CAFE
# 4                4    2020-02-04   FA0240932  THE GREAT ROOM CAFE
# ...            ...           ...         ...                  ...
# 758825      758825    2018-08-27   FA0222602         CHOP STOP #5
# 758826      758826    2018-02-15   FA0068935                MAYAN
# 758827      758827    2018-02-15   FA0068935                MAYAN
# 758828      758828    2018-02-15   FA0068935                MAYAN
# 758829      758829    2018-02-15   FA0068935                MAYAN
#
#                PROGRAM_NAME PROGRAM_STATUS   FACILITY_ADDRESS  \
# 0       THE GREAT ROOM CAFE         ACTIVE  2810 ARTESIA BLVD
# 1       THE GREAT ROOM CAFE         ACTIVE  2810 ARTESIA BLVD
# 2       THE GREAT ROOM CAFE         ACTIVE  2810 ARTESIA BLVD
# 3       THE GREAT ROOM CAFE         ACTIVE  2810 ARTESIA BLVD
# 4       THE GREAT ROOM CAFE         ACTIVE  2810 ARTESIA BLVD
# ...                     ...            ...                ...
# 758825         CHOP STOP #5         ACTIVE   601 GLENDALE AVE
# 758826                MAYAN         ACTIVE     1038 S HILL ST
# 758827                MAYAN         ACTIVE     1038 S HILL ST
# 758828                MAYAN         ACTIVE     1038 S HILL ST
# 758829                MAYAN         ACTIVE     1038 S HILL ST
#
#                FACILITY_CITY FACILITY_STATE  FACILITY_ZIP  SCORE GRADE  \
# 0              REDONDO BEACH             CA         90278     91     A
# 1              REDONDO BEACH             CA         90278     91     A
# 2              REDONDO BEACH             CA         90278     91     A
# 3              REDONDO BEACH             CA         90278     91     A
# 4              REDONDO BEACH             CA         90278     91     A
# ...                      ...            ...           ...    ...   ...
# 758825              GLENDALE             CA         91206     98     A
# 758826  LOS ANGELES, CITY OF             CA         90015     96     A
# 758827  LOS ANGELES, CITY OF             CA         90015     96     A
# 758828  LOS ANGELES, CITY OF             CA         90015     96     A
# 758829  LOS ANGELES, CITY OF             CA         90015     96     A
#
#        serial_number         LAT        LNG   violation_status violation_code  \
# 0          DA000B8AV -118.358308  33.872838  OUT OF COMPLIANCE           F007
# 1          DA000B8AV -118.358308  33.872838  OUT OF COMPLIANCE           F034
# 2          DA000B8AV -118.358308  33.872838  OUT OF COMPLIANCE           F040
# 3          DA000B8AV -118.358308  33.872838  OUT OF COMPLIANCE           F037
# 4          DA000B8AV -118.358308  33.872838  OUT OF COMPLIANCE           F006
# ...              ...         ...        ...                ...            ...
# 758825     DAZZXWPZN -118.243261  34.154154  OUT OF COMPLIANCE           F034
# 758826     DAZZY0TED -118.259326  34.040671  OUT OF COMPLIANCE           F037
# 758827     DAZZY0TED -118.259326  34.040671  OUT OF COMPLIANCE           F040
# 758828     DAZZY0TED -118.259326  34.040671  OUT OF COMPLIANCE           F044
# 758829     DAZZY0TED -118.259326  34.040671  OUT OF COMPLIANCE           F036
#
#                                     violation_description  points  \
# 0          # 07. Proper hot and cold holding temperatures     4.0
# 1       # 34. Warewashing facilities: Adequate, mainta...     1.0
# 2       # 40. Plumbing: Plumbing in good repair, prope...     1.0
# 3       # 37. Adequate ventilation and lighting; desig...     1.0
# 4       # 06. Adequate handwashing facilities supplied...     2.0
# ...                                                   ...     ...
# 758825  # 34. Warewashing facilities: Adequate, mainta...     1.0
# 758826  # 37. Adequate ventilation and lighting; desig...     1.0
# 758827  # 40. Plumbing: Plumbing in good repair, prope...     1.0
# 758828  # 44. Floors, walls and ceilings: properly bui...     1.0
# 758829  # 36. Equipment, utensils and linens: storage ...     1.0
#
#                      GEONAME    Pop_Tot  Prop_18y  Prop_64y  Prop_65y+  \
# 0              REDONDO BEACH    69316.0    0.2056    0.6614     0.1330
# 1              REDONDO BEACH    69316.0    0.2056    0.6614     0.1330
# 2              REDONDO BEACH    69316.0    0.2056    0.6614     0.1330
# 3              REDONDO BEACH    69316.0    0.2056    0.6614     0.1330
# 4              REDONDO BEACH    69316.0    0.2056    0.6614     0.1330
# ...                      ...        ...       ...       ...        ...
# 758825              GLENDALE   201604.0    0.1690    0.6548     0.1762
# 758826  LOS ANGELES, CITY OF  4032993.0    0.2221    0.6574     0.1205
# 758827  LOS ANGELES, CITY OF  4032993.0    0.2221    0.6574     0.1205
# 758828  LOS ANGELES, CITY OF  4032993.0    0.2221    0.6574     0.1205
# 758829  LOS ANGELES, CITY OF  4032993.0    0.2221    0.6574     0.1205
#
#         Prop_Blk  Prop_Lat  Prop_Whi  Prop_Asi  Prop_Ami  Prop_NHO  Prop_FPL1  \
# 0         0.0272    0.1567    0.6806    0.1302    0.0025    0.0028     0.0462
# 1         0.0272    0.1567    0.6806    0.1302    0.0025    0.0028     0.0462
# 2         0.0272    0.1567    0.6806    0.1302    0.0025    0.0028     0.0462
# 3         0.0272    0.1567    0.6806    0.1302    0.0025    0.0028     0.0462
# 4         0.0272    0.1567    0.6806    0.1302    0.0025    0.0028     0.0462
# ...          ...       ...       ...       ...       ...       ...        ...
# 758825    0.0120    0.1755    0.6382    0.1727    0.0010    0.0005     0.1318
# 758826    0.0912    0.5004    0.2888    0.1168    0.0017    0.0011     0.2031
# 758827    0.0912    0.5004    0.2888    0.1168    0.0017    0.0011     0.2031
# 758828    0.0912    0.5004    0.2888    0.1168    0.0017    0.0011     0.2031
# 758829    0.0912    0.5004    0.2888    0.1168    0.0017    0.0011     0.2031
#
#         Prop_FPL2  Prop_forb  Prop_Eng  Prop_edLH  Prop_edHG  Prop_edSC  \
# 0          0.0957     0.1877    0.0393     0.0415     0.1110     0.2785
# 1          0.0957     0.1877    0.0393     0.0415     0.1110     0.2785
# 2          0.0957     0.1877    0.0393     0.0415     0.1110     0.2785
# 3          0.0957     0.1877    0.0393     0.0415     0.1110     0.2785
# 4          0.0957     0.1877    0.0393     0.0415     0.1110     0.2785
# ...           ...        ...       ...        ...        ...        ...
# 758825     0.2943     0.5444    0.2522     0.1564     0.1908     0.2738
# 758826     0.4241     0.3820    0.1575     0.2453     0.1963     0.2387
# 758827     0.4241     0.3820    0.1575     0.2453     0.1963     0.2387
# 758828     0.4241     0.3820    0.1575     0.2453     0.1963     0.2387
# 758829     0.4241     0.3820    0.1575     0.2453     0.1963     0.2387
#
#         Prop_edCG       MHI  Prop_groc  Prop_60mi  No_farm  Prop_obse  \
# 0          0.5689  105145.0     0.7645      0.116        2     0.1971
# 1          0.5689  105145.0     0.7645      0.116        2     0.1971
# 2          0.5689  105145.0     0.7645      0.116        2     0.1971
# 3          0.5689  105145.0     0.7645      0.116        2     0.1971
# 4          0.5689  105145.0     0.7645      0.116        2     0.1971
# ...           ...       ...        ...        ...      ...        ...
# 758825     0.3790   52574.0     0.7505      0.098        1     0.1516
# 758826     0.3197   50205.0     0.6835      0.121       58     0.2193
# 758827     0.3197   50205.0     0.6835      0.121       58     0.2193
# 758828     0.3197   50205.0     0.6835      0.121       58     0.2193
# 758829     0.3197   50205.0     0.6835      0.121       58     0.2193
#
#         Prop_DM   Rte_CVD  Prop_ownr  Prop_rentr  No_hless  Rte_crim  \
# 0        0.0599  177.9619      0.499       0.501     216.0     231.0
# 1        0.0599  177.9619      0.499       0.501     216.0     231.0
# 2        0.0599  177.9619      0.499       0.501     216.0     231.0
# 3        0.0599  177.9619      0.499       0.501     216.0     231.0
# 4        0.0599  177.9619      0.499       0.501     216.0     231.0
# ...         ...       ...        ...         ...       ...       ...
# 758825   0.0716  181.4710      0.353       0.647     240.0     113.0
# 758826   0.1006  205.0990      0.368       0.632   28464.0     620.0
# 758827   0.1006  205.0990      0.368       0.632   28464.0     620.0
# 758828   0.1006  205.0990      0.368       0.632   28464.0     620.0
# 758829   0.1006  205.0990      0.368       0.632   28464.0     620.0
#
#         Rte_alco  Propt_envi  Prop_depr  Propt_HPI  Prop_fru  Prop_bev  \
# 0           26.0          84     0.1129       93.0       0.2       0.2
# 1           26.0          84     0.1129       93.0       0.2       0.2
# 2           26.0          84     0.1129       93.0       0.2       0.2
# 3           26.0          84     0.1129       93.0       0.2       0.2
# 4           26.0          84     0.1129       93.0       0.2       0.2
# ...          ...         ...        ...        ...       ...       ...
# 758825      17.0           1     0.0980       46.1       0.1       0.3
# 758826      15.0          21     0.0925       28.6       0.2       0.4
# 758827      15.0          21     0.0925       28.6       0.2       0.4
# 758828      15.0          21     0.0925       28.6       0.2       0.4
# 758829      15.0          21     0.0925       28.6       0.2       0.4
#
#         Prop_hyp  Prop_marj  new_seats ACTIVITY_DATE_MONTHYEAR  \
# 0            0.2        0.1         61                 2020-02
# 1            0.2        0.1         61                 2020-02
# 2            0.2        0.1         61                 2020-02
# 3            0.2        0.1         61                 2020-02
# 4            0.2        0.1         61                 2020-02
# ...          ...        ...        ...                     ...
# 758825       0.2        0.2          0                 2018-08
# 758826       0.2        0.1        151                 2018-02
# 758827       0.2        0.1        151                 2018-02
# 758828       0.2        0.1        151                 2018-02
# 758829       0.2        0.1        151                 2018-02
#
#         ACTIVITY_DATE_MONTH
# 0                         2
# 1                         2
# 2                         2
# 3                         2
# 4                         2
# ...                     ...
# 758825                    8
# 758826                    2
# 758827                    2
# 758828                    2
# 758829                    2
#
# [758830 rows x 60 columns]

# %%
#drop columns
rats2_ml_df=restaurant_list_df.drop(["Unnamed: 0","ACTIVITY_DATE","ACTIVITY_DATE_MONTHYEAR","serial_number","FACILITY_ID","FACILITY_NAME","PROGRAM_NAME","PROGRAM_STATUS","FACILITY_ADDRESS","FACILITY_STATE","FACILITY_CITY","GRADE","violation_status","violation_code","violation_description","GEONAME","Pop_Tot","Prop_18y","Prop_64y","Prop_65y+","Prop_Blk","Prop_Lat","Prop_Whi","Prop_Asi","Prop_Asi","Prop_Ami","Prop_NHO","Prop_FPL1","Prop_FPL2","Prop_forb", "Prop_Eng", "Prop_edLH", "Prop_edHG", "Prop_edSC", "Prop_edCG","MHI","Prop_groc", "Prop_60mi", "No_farm", "Prop_obse", "Prop_DM","Rte_CVD","Prop_ownr","Prop_rentr","No_hless", "Rte_crim","Rte_alco","Propt_envi","Prop_depr","Propt_HPI","Prop_fru","Prop_bev","Prop_hyp","Prop_marj"],1)
rats2_ml_df
# Out:
#         FACILITY_ZIP  SCORE         LAT        LNG  points  new_seats  \
# 0              90278     91 -118.358308  33.872838     4.0         61
# 1              90278     91 -118.358308  33.872838     1.0         61
# 2              90278     91 -118.358308  33.872838     1.0         61
# 3              90278     91 -118.358308  33.872838     1.0         61
# 4              90278     91 -118.358308  33.872838     2.0         61
# ...              ...    ...         ...        ...     ...        ...
# 758825         91206     98 -118.243261  34.154154     1.0          0
# 758826         90015     96 -118.259326  34.040671     1.0        151
# 758827         90015     96 -118.259326  34.040671     1.0        151
# 758828         90015     96 -118.259326  34.040671     1.0        151
# 758829         90015     96 -118.259326  34.040671     1.0        151
#
#         ACTIVITY_DATE_MONTH
# 0                         2
# 1                         2
# 2                         2
# 3                         2
# 4                         2
# ...                     ...
# 758825                    8
# 758826                    2
# 758827                    2
# 758828                    2
# 758829                    2
#
# [758830 rows x 7 columns]

# %%
# Define the features set.
X = rats2_ml_df.copy()
X = X.drop("SCORE", axis=1)
X.head()
# Out:
#    FACILITY_ZIP         LAT        LNG  points  new_seats  ACTIVITY_DATE_MONTH
# 0         90278 -118.358308  33.872838     4.0         61                    2
# 1         90278 -118.358308  33.872838     1.0         61                    2
# 2         90278 -118.358308  33.872838     1.0         61                    2
# 3         90278 -118.358308  33.872838     1.0         61                    2
# 4         90278 -118.358308  33.872838     2.0         61                    2

# %%
# Define the target set.
y = rats2_ml_df["SCORE"].ravel()
y[:5]
# Out:
# array([91, 91, 91, 91, 91])

# %%
# Splitting into Train and Test sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=78)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data.
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix.
cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1","Actual 2","Actual 3","Actual 4", "Actual 5","Actual 6","Actual 7", "Actual 8", "Actual 9","Actual 10","Actual 11","Actual 12", "Actual 13","Actual 14","Actual 15", "Actual 16", "Actual 17","Actual 18","Actual 19","Actual 20", "Actual 21","Actual 22","Actual 23", "Actual 24", "Actual 25","Actual 26","Actual 27","Actual 28", "Actual 29","Actual 30"], columns=[ "Predicted 0", "Predicted 1","Predicted 2","Predicted 3","Predicted 4", "Predicted 5","Predicted 6","Predicted 7", "Predicted 8", "Predicted 9","Predicted 10","Predicted 11","Predicted 12", "Predicted13","Predicted 14","Predicted 15", "Predicted 16", "Predicted 17","Predicted 18","Predicted 19","Predicted 20", "Predicted 21","Predicted 22","Predicted 23", "Predicted 24", "Predicted 25","Predicted 26","Predicted 27","Predicted 28", "Predicted 29","Predicted 30"])

cm_df
# Out:
#            Predicted 0  Predicted 1  Predicted 2  Predicted 3  Predicted 4  \
# Actual 0           238            1            0            0            0
# Actual 1             4          250            0            3            0
# Actual 2             0            2          186            3            0
# Actual 3             1            0            1          205            0
# Actual 4             1            0            0            3          263
# Actual 5             0            0            0            0            0
# Actual 6             0            0            0            3            3
# Actual 7             2            0            0            0            4
# Actual 8             1            0            1            3            0
# Actual 9             0            0            0            4            5
# Actual 10            3           15            0            3           11
# Actual 11            7            4            2            6            7
# Actual 12           10            8            0            4            8
# Actual 13            2            1            9            4            3
# Actual 14            7            3            8           13            1
# Actual 15           13            2            5            5            8
# Actual 16            5            2            2            3            4
# Actual 17            1            5            0            0            0
# Actual 18            3            0            3            3            2
# Actual 19            0            0            0            0            0
# Actual 20           29           16           18           29           47
# Actual 21            6            9           12            8           20
# Actual 22           17            9            5           10           29
# Actual 23           10           13            7            5            5
# Actual 24            3            2            5           13            7
# Actual 25            4            0            3            5            8
# Actual 26            0            1            5            8            6
# Actual 27            1            4            2            3            4
# Actual 28            0            0            2            1            1
# Actual 29            0            0            1            0            1
# Actual 30            0            0            0            0            0
#
#            Predicted 5  Predicted 6  Predicted 7  Predicted 8  Predicted 9  \
# Actual 0             0            0            0            0            0
# Actual 1             0            1            0            0            0
# Actual 2             0            0            0            0            0
# Actual 3             1            0            3            0            1
# Actual 4             0            0            1            1            2
# Actual 5           294            2            5            3            0
# Actual 6             0          274            0            1            0
# Actual 7             1            6          275            4            0
# Actual 8             0            0            0          166            0
# Actual 9             1            0            0            0           42
# Actual 10            3            8            9            3            1
# Actual 11           14            2            4            9            3
# Actual 12            2            8            2            1            4
# Actual 13            4           12            4            1            1
# Actual 14            3            1            3            4            2
# Actual 15            2            8            7            0            4
# Actual 16            3            3            0            3            5
# Actual 17            3            1            0            0            1
# Actual 18            1            2            0            0            0
# Actual 19            0            0            0            0            0
# Actual 20           28           26           14           20            5
# Actual 21           11           11           20            6            1
# Actual 22           20           12           19            5            1
# Actual 23            5           14            7            9            0
# Actual 24            8            8           19           11            2
# Actual 25            7            9            4            7            2
# Actual 26           10           11            6           13            0
# Actual 27            3            5            4            1            3
# Actual 28            1            1            0            2            1
# Actual 29            0            1            0            0            0
# Actual 30            0            0            0            0            0
#
#            Predicted 10  Predicted 11  Predicted 12  Predicted13  \
# Actual 0              6             9             5            0
# Actual 1             11             4             1            1
# Actual 2              2             4             5            2
# Actual 3              6             3             0            3
# Actual 4             12             5             5            2
# Actual 5              8             6             1            5
# Actual 6              8             5             6            2
# Actual 7             10             6             7            8
# Actual 8              5             5             1            0
# Actual 9              1             1             1            1
# Actual 10          2578            30            33           39
# Actual 11            62          1380            32           44
# Actual 12            53            27          1423           42
# Actual 13            47            22            29         1535
# Actual 14            49            27            19           17
# Actual 15            30            28            36           26
# Actual 16            66            21            19           16
# Actual 17            20            25            18           11
# Actual 18             5             6             8           10
# Actual 19             1             1             0            5
# Actual 20           419           178           174          181
# Actual 21           127            80            94           93
# Actual 22           143            61            58           66
# Actual 23           121            56            71           88
# Actual 24           103            48            52           58
# Actual 25            86            37            47           56
# Actual 26            65            24            44           45
# Actual 27            29             6            19           24
# Actual 28            18             8             9           22
# Actual 29             7             4             6            2
# Actual 30             1             0             0            0
#
#            Predicted 14  Predicted 15  Predicted 16  Predicted 17  \
# Actual 0              4             0             2             1
# Actual 1              5             4             0             2
# Actual 2              0             3             4             0
# Actual 3              0             0             1             2
# Actual 4              0             4             3             1
# Actual 5              4             3             0             2
# Actual 6              4             6             0             0
# Actual 7              7             2             5             2
# Actual 8              0             1             5             0
# Actual 9              1             7             1             0
# Actual 10            26            25            22            10
# Actual 11            26            16            12            14
# Actual 12            31            30            25            19
# Actual 13            34            19            18             7
# Actual 14          1580            31            22            17
# Actual 15            29          1520            15             9
# Actual 16            30            24          1206             6
# Actual 17            15             8            13           815
# Actual 18             5             2            11             6
# Actual 19             1             1             0             0
# Actual 20           192           181           195           115
# Actual 21            78            87            64            57
# Actual 22            69            65            82            49
# Actual 23            94            89            66            53
# Actual 24            85            91            55            38
# Actual 25            48            61            47            26
# Actual 26            41            60            44            33
# Actual 27            32            23            22            13
# Actual 28            20            13            16             8
# Actual 29             2             1             3             2
# Actual 30             0             0             0             0
#
#            Predicted 18  Predicted 19  Predicted 20  Predicted 21  \
# Actual 0              0             0            17            13
# Actual 1              0             0            25             1
# Actual 2              1             0            26             2
# Actual 3              0             0            18             3
# Actual 4              0             0            34             9
# Actual 5              1             0            40             6
# Actual 6              0             0            22             5
# Actual 7              5             0            25            18
# Actual 8              2             0            14            10
# Actual 9              0             0             2             0
# Actual 10             3             0           390           115
# Actual 11             5             0           166            67
# Actual 12             4             1           181            73
# Actual 13             9             0           198            92
# Actual 14             8             4           211           117
# Actual 15             2             0           176            87
# Actual 16             5             1           149            83
# Actual 17             9             0           130            61
# Actual 18           322             0            44            18
# Actual 19             0            55            10             4
# Actual 20            38             5         28022          1648
# Actual 21            18             3          2052         14346
# Actual 22            13             0          1801           905
# Actual 23            17             0          1712           981
# Actual 24            11             1          1556           929
# Actual 25            16             1          1227           698
# Actual 26            19             2           819           471
# Actual 27             4             0           517           337
# Actual 28             3             1           253           157
# Actual 29             2             0            81            79
# Actual 30             0             0             0             1
#
#            Predicted 22  Predicted 23  Predicted 24  Predicted 25  \
# Actual 0              8             9             9             0
# Actual 1              8             3             0             0
# Actual 2              4             0             4             2
# Actual 3              1             4             1             0
# Actual 4              6             6             1             2
# Actual 5              4            12             4             5
# Actual 6              8            11             4             5
# Actual 7              5             2             2             2
# Actual 8              1             4             3             0
# Actual 9              0             2             0             0
# Actual 10           108            86            49            45
# Actual 11            75            50            39            18
# Actual 12            48            56            32            29
# Actual 13            67            47            45            21
# Actual 14            70            43            41            35
# Actual 15            77            45            57            38
# Actual 16            73            41            40            30
# Actual 17            68            28            43            20
# Actual 18            32            19            14             8
# Actual 19             5             3             3             5
# Actual 20          1293          1109           951           683
# Actual 21           881           874           662           498
# Actual 22         13892           921           726           569
# Actual 23           961         13529           905           737
# Actual 24           915           965         12984           967
# Actual 25           797           990           999         11260
# Actual 26           630           661           821           903
# Actual 27           433           507           584           714
# Actual 28           171           217           322           395
# Actual 29            76            91           148           161
# Actual 30             0             0             0             0
#
#            Predicted 26  Predicted 27  Predicted 28  Predicted 29  \
# Actual 0              0             0             0             0
# Actual 1              0             0             0             0
# Actual 2              0             0             2             0
# Actual 3              5             1             0             0
# Actual 4              0             1             0             0
# Actual 5              8             3             0             0
# Actual 6              0             0             0             0
# Actual 7              2             0             0             0
# Actual 8              1             1             0             0
# Actual 9              0             0             0             0
# Actual 10            18             8             0             0
# Actual 11            12             3             4             0
# Actual 12            11             7             8             0
# Actual 13            17             6             2             2
# Actual 14            16             4             9             0
# Actual 15            31            20             1             0
# Actual 16            24            16            13             0
# Actual 17            14            13             7             2
# Actual 18            10             8             0             1
# Actual 19             0             0             0             0
# Actual 20           417           213            60             4
# Actual 21           292           161            47            18
# Actual 22           410           225            69            17
# Actual 23           471           296            98            28
# Actual 24           680           404           118            17
# Actual 25           824           431           235            40
# Actual 26          9252           578           290            63
# Actual 27           781          5791           382            95
# Actual 28           478           489          2808            99
# Actual 29           176           249           245           158
# Actual 30             0             0             0             0
#
#            Predicted 30
# Actual 0              0
# Actual 1              0
# Actual 2              0
# Actual 3              0
# Actual 4              0
# Actual 5              0
# Actual 6              0
# Actual 7              0
# Actual 8              0
# Actual 9              0
# Actual 10             0
# Actual 11             0
# Actual 12             0
# Actual 13             0
# Actual 14             0
# Actual 15             0
# Actual 16             0
# Actual 17             0
# Actual 18             0
# Actual 19             0
# Actual 20             0
# Actual 21             0
# Actual 22             0
# Actual 23             0
# Actual 24             0
# Actual 25             0
# Actual 26             0
# Actual 27             0
# Actual 28             0
# Actual 29             0
# Actual 30             3

# %%
# Calculating the accuracy score.
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
#print("Confusion Matrix")
#display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Accuracy Score : 0.6621281126784321
# Classification Report
#               precision    recall  f1-score   support
#
#           70       0.62      0.70      0.66       322
#           71       0.72      0.74      0.73       323
#           72       0.66      0.70      0.68       252
#           73       0.58      0.77      0.66       260
#           74       0.56      0.68      0.62       362
#           75       0.67      0.69      0.68       416
#           76       0.63      0.72      0.67       367
#           77       0.65      0.66      0.65       400
#           78       0.59      0.68      0.63       224
#           79       0.51      0.61      0.55        69
#           80       0.60      0.69      0.64      3641
#           81       0.63      0.64      0.64      2083
#           82       0.63      0.65      0.64      2147
#           83       0.62      0.66      0.64      2258
#           84       0.63      0.65      0.64      2365
#           85       0.63      0.66      0.64      2281
#           86       0.61      0.62      0.62      1893
#           87       0.62      0.60      0.61      1331
#           88       0.62      0.59      0.60       543
#           89       0.74      0.57      0.65        94
#           90       0.69      0.77      0.73     36310
#           91       0.67      0.69      0.68     20636
#           92       0.67      0.68      0.67     20268
#           93       0.66      0.66      0.66     20448
#           94       0.67      0.64      0.65     20155
#           95       0.65      0.62      0.64     17975
#           96       0.66      0.62      0.64     14925
#           97       0.65      0.56      0.60     10343
#           98       0.64      0.51      0.57      5516
#           99       0.28      0.10      0.14      1496
#          100       1.00      0.60      0.75         5
#
#     accuracy                           0.66    189708
#    macro avg       0.64      0.64      0.63    189708
# weighted avg       0.66      0.66      0.66    189708

# %%
# Calculate feature importance in the Random Forest model.
importances = rf_model.feature_importances_
importances
# Out:
# array([0.06358609, 0.31206531, 0.31094569, 0.01154252, 0.03234775,
#        0.26951263])

# %%
# We can sort the features by their importance.
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.31206531494092227, 'LAT'),
#  (0.3109456897931746, 'LNG'),
#  (0.2695126315813, 'ACTIVITY_DATE_MONTH'),
#  (0.06358609368874318, 'FACILITY_ZIP'),
#  (0.03234774612350595, 'new_seats'),
#  (0.01154252387235398, 'points')]
