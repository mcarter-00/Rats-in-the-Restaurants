# %%
import pandas as pd

# %%
data = pd.read_csv("./Resources/Los_Angeles_County_City_and_Community_Health_Profiles_2018.csv", index_col = 0)
data
# Out:
#                            Pop_Tot  Prop_18y  Prop_64y  Prop_65y+  Prop_Blk  \
# GEONAME
# Alhambra                     86705    0.1831    0.6504     0.1665    0.0133
# Altadena                     42525    0.2072    0.6221     0.1707    0.2374
# Arcadia                      56992    0.1794    0.6389     0.1817    0.0115
# Azusa                        49479    0.2507    0.6538     0.0956    0.0292
# Baldwin Park                 74438    0.2623    0.6330     0.1047    0.0099
# ...                            ...       ...       ...        ...       ...
# West Hollywood               35797    0.0639    0.7801     0.1560    0.0310
# West Whittier-Los Nietos     25441    0.2426    0.6253     0.1321    0.0080
# Westmont                     32835    0.2823    0.6208     0.0968    0.4945
# Whittier                     88078    0.2304    0.6385     0.1311    0.0098
# Los Angeles County        10227450    0.2253    0.6471     0.1276    0.0846
#
# ...

# %%
print(data.columns)
# Out:
# Index(['Pop_Tot', 'Prop_18y', 'Prop_64y', 'Prop_65y+', 'Prop_Blk', 'Prop_Lat',
#        'Prop_Whi', 'Prop_Asi', 'Prop_Ami', 'Prop_NHO', 'Prop_FPL1',
#        'Prop_FPL2', 'Prop_forb', 'Prop_Eng', 'LE', 'Prop_prsc', 'Prop_3rdg',
#        'Prop_edLH', 'Prop_edHG', 'Prop_edSC', 'Prop_edCG', 'MHI', 'No_libr',
#        'Prop_empl', 'Prop_emsu', 'Prop_vote', 'Rte_resp', 'Prop_PA',
#        'Prop_groc', 'Prop_60mi', 'No_farm', 'No_EBT', 'Prop_foin', 'No_CalF',
#        'Rte_CalF', 'Prop_FRPM', 'Prop_obse', 'Prop_DM', 'Rte_coin', 'Rte_brin',
#        'Prop_smok', 'Rte_luca', 'Rte_COPD', 'Rte_CVD', 'Prop_hbu1',
#        'Prop_hbu2', 'Prop_ownr', 'Prop_rentr', 'No_hless', 'Prop_asth',
#        'Rte_crim', 'Rte_hom', 'Rte_alco', 'Propt_envi', 'No_gasw', 'Rte_te17',
#        'Rte_te19', 'Prop_LBW', 'Rte_IMR', 'Prop_1stt', 'Prop_depr', 'Rte_suic',
#        'Rte_UOD', 'Rte_syin', 'Rte_goin', 'Rte_hiv', 'Prop_uinC', 'Prop_uinA',
# ...

# %%
data.isnull().count()
# Out:
# Pop_Tot      87
# Prop_18y     87
# Prop_64y     87
# Prop_65y+    87
# Prop_Blk     87
#              ..
# Prop_hyp     87
# Prop_marj    87
# Prop_HI      87
# Prop_grad    87
# Prop_trua    87
# Length: 81, dtype: int64

# %%
scores = data[["Propt_envi", "Propt_HPI"]]
scores
# Out:
#                          Propt_envi Propt_HPI
# GEONAME
# Alhambra                          6      43.3
# Altadena                         62      75.5
# Arcadia                          27      73.4
# Azusa                            48      34.2
# Baldwin Park                      9      22.3
# ...                             ...       ...
# West Hollywood                   29      70.6
# West Whittier-Los Nietos         26      41.2
# Westmont                         69       0.6
# Whittier                         63      53.8
# Los Angeles County                -         -
#
# [87 rows x 2 columns]

# %% [markdown]
# * Propt_envi = California Healthy Places Index Clean Environment Score rank percentile
# * Propt_HPI = California Healthy Places Index (HPI) Score rank percentile
